# %%
import collections
import numpy as np
import pandas as pd
import re

from argparse import Namespace

# %%
args = Namespace(
    train_dataset_csv="train.csv",
    test_dataset_csv="test.csv",
    train_proportion=0.7,
    val_proportion=0.3,
    train_split_csv="train_with_splits.csv",
    seed=523
)

# %%
train=pd.read_csv(args.train_dataset_csv)
train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
train.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
train[train.keyword.notnull()]
# Out:
#          id  keyword                       location  \
# 31       48   ablaze                     Birmingham
# 32       49   ablaze  Est. September 2012 - Bristol
# 33       50   ablaze                         AFRICA
# 34       52   ablaze               Philadelphia, PA
# 35       53   ablaze                     London, UK
# ...     ...      ...                            ...
# 7578  10830  wrecked                            NaN
# 7579  10831  wrecked              Vancouver, Canada
# 7580  10832  wrecked                        London
# 7581  10833  wrecked                        Lincoln
# 7582  10834  wrecked                            NaN
#
#                                                    text  target
# 31    @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 32    We always try to bring the heavy. #metal #RT h...       0
# 33    #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 34                   Crying out for more! Set me ablaze       0
# 35    On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# ...                                                 ...     ...
# 7578   @jt_ruff23 @cameronhacker and I wrecked you both       0
# 7579  Three days off from work and they've pretty mu...       0
# 7580  #FX #forex #trading Cramer: Iger's 3 words tha...       0
# 7581  @engineshed Great atmosphere at the British Li...       0
# 7582  Cramer: Iger's 3 words that wrecked Disney's s...       0
#
# [7552 rows x 5 columns]

# %%
train.keyword.nunique()
# Out:
# 221

# %%
train.target.sum()/len(train)
# Out:
# 0.4296597924602653

# %%
train.location.nunique()/train.location.notnull().sum()
# Out:
# 0.6576771653543307

# %%
# Splitting train by target
# Create dict
by_target = collections.defaultdict(list)
for _, row in train.iterrows():
    by_target[row.target].append(row.to_dict())

# %%
by_target
# Out:
# defaultdict(list,
#             {1: [{'id': 1,
#                'keyword': nan,
#                'location': nan,
#                'text': 'Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all',
#                'target': 1},
#               {'id': 4,
#                'keyword': nan,
#                'location': nan,
#                'text': 'Forest fire near La Ronge Sask. Canada',
#                'target': 1},
#               {'id': 5,
#                'keyword': nan,
#                'location': nan,
#                'text': "All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected",
#                'target': 1},
#               {'id': 6,
#                'keyword': nan,
#                'location': nan,
#                'text': '13,000 people receive #wildfires evacuation orders in California ',
#                'target': 1},
#               {'id': 7,
#                'keyword': nan,
#                'location': nan,
#                'text': 'Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school ',
#                'target': 1},
#               {'id': 8,
#                'keyword': nan,
#                'location': nan,
#                'text': '#RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires',
#                'target': 1},
#               {'id': 10,
#                'keyword': nan,
#                'location': nan,
#                'text': '#flood #disaster Heavy rain causes flash flooding of streets in Manitou, Colorado Springs areas',
#                'target': 1},
#               {'id': 13,
#                'keyword': nan,
#                'location': nan,
#                'text': "I'm on top of the hill and I can see a fire in the woods...",
#                'target': 1},
#               {'id': 14,
#                'keyword': nan,
#                'location': nan,
#                'text': "There's an emergency evacuation happening now in the building across the street",
#                'target': 1},
#               {'id': 15,
#                'keyword': nan,
#                'location': nan,
#                'text': "I'm afraid that the tornado is coming to our area...",
#                'target': 1},
#               {'id': 16,
#                'keyword': nan,
#                'location': nan,
#                'text': 'Three people died from the heat wave so far',
#                'target': 1},
#               {'id': 17,
#                'keyword': nan,
#                'location': nan,
#                'text': 'Haha South Tampa is getting flooded hah- WAIT A SECOND I LIVE IN SOUTH TAMPA WHAT AM I GONNA DO WHAT AM I GONNA DO FVCK #flooding',
#                'target': 1},
#               {'id': 18,
#                'keyword': nan,
#                'location': nan,
#                'text': "#raining #flooding #Florida #TampaBay #Tampa 18 or 19 days. I've lost count ",
#                'target': 1},
#               {'id': 19,
#                'keyword': nan,
#                'location': nan,
#                'text': '#Flood in Bago Myanmar #We arrived Bago',
#                'target': 1},
#               {'id': 20,
#                'keyword': nan,
#                'location': nan,
#                'text': 'Damage to school bus on 80 in multi car crash #BREAKING ',
#                'target': 1},
#               {'id': 48,
#                'keyword': 'ablaze',
#                'location': 'Birmingham',
#                'text': '@bbcmtd Wholesale Markets ablaze http://t.co/lHYXEOHY6C',
#                'target': 1},
#               {'id': 50,
#                'keyword': 'ablaze',
#                'location': 'AFRICA',
#                'text': '#AFRICANBAZE: Breaking news:Nigeria flag set ablaze in Aba. http://t.co/2nndBGwyEi',
#                'target': 1},
#               {'id': 55,
#                'keyword': 'ablaze',
#                'location': 'World Wide!!',
#                'text': 'INEC Office in Abia Set Ablaze - http://t.co/3ImaomknnA',
#                'target': 1},
#               {'id': 56,
#                'keyword': 'ablaze',
#                'location': nan,
#                'text': 'Barbados #Bridgetown JAMAICA \x89ÛÒ Two cars set ablaze: SANTA CRUZ \x89ÛÓ Head of the St Elizabeth Police Superintende...  http://t.co/wDUEaj8Q4J',
#                'target': 1},
#               {'id': 66,
#                'keyword': 'ablaze',
#                'location': 'GREENSBORO,NORTH CAROLINA',
#                'text': 'How the West was burned: Thousands of wildfires ablaze in California alone http://t.co/vl5TBR3wbr',
#                'target': 1},
#               {'id': 73,
#                'keyword': 'ablaze',
#                'location': 'Sheffield Township, Ohio',
#                'text': 'Deputies: Man shot before Brighton home set ablaze http://t.co/gWNRhMSO8k',
#                'target': 1},
#               {'id': 74,
#                'keyword': 'ablaze',
#                'location': 'India',
#                'text': 'Man wife get six years jail for setting ablaze niece\nhttp://t.co/eV1ahOUCZA',
#                'target': 1},
#               {'id': 77,
#                'keyword': 'ablaze',
#                'location': 'Anaheim',
#                'text': 'Police: Arsonist Deliberately Set Black Church In North CarolinaåÊAblaze http://t.co/pcXarbH9An',
#                'target': 1},
#               {'id': 79,
#                'keyword': 'ablaze',
#                'location': 'USA',
#                'text': '#Kurds trampling on Turkmen flag later set it ablaze while others vandalized offices of Turkmen Front in #Diyala http://t.co/4IzFdYC3cg',
#                'target': 1},
#               {'id': 80,
#                'keyword': 'ablaze',
#                'location': 'South Africa',
#                'text': 'TRUCK ABLAZE : R21. VOORTREKKER AVE. OUTSIDE OR TAMBO INTL. CARGO SECTION. http://t.co/8kscqKfKkF',
#                'target': 1},
#               {'id': 83,
#                'keyword': 'ablaze',
#                'location': 'Edmonton, Alberta - Treaty 6',
#                'text': 'How the West was burned: Thousands of wildfires ablaze in #California alone http://t.co/iCSjGZ9tE1 #climate #energy http://t.co/9FxmN0l0Bd',
#                'target': 1},
#               {'id': 91,
#                'keyword': 'ablaze',
#                'location': 'Concord, CA',
#                'text': "@Navista7 Steve these fires out here are something else! California is a tinderbox - and this clown was setting my 'hood ablaze @News24680",
#                'target': 1},
#               {'id': 93,
#                'keyword': 'ablaze',
#                'location': 'Birmingham',
#                'text': '@nxwestmidlands huge fire at Wholesale markets ablaze http://t.co/rwzbFVNXER',
#                'target': 1},
#               {'id': 97,
#                'keyword': 'accident',
#                'location': 'Nashville, TN',
#                'text': 'Accident on I-24 W #NashvilleTraffic. Traffic moving 8m slower than usual. https://t.co/0GHk693EgJ',
#                'target': 1},
#               {'id': 98,
#                'keyword': 'accident',
#                'location': 'Santa Clara, CA',
#                'text': 'Accident center lane blocked in #SantaClara on US-101 NB before Great America Pkwy #BayArea #Traffic http://t.co/pmlOhZuRWR',
#                'target': 1},
#               {'id': 104,
#                'keyword': 'accident',
#                'location': 'Walker County, Alabama',
#                'text': 'Reported motor vehicle accident in Curry on Herman Rd near Stephenson involving an overturned vehicle. Please use... http://t.co/YbJezKuRW1',
#                'target': 1},
#               {'id': 105,
#                'keyword': 'accident',
#                'location': 'Australia',
#                'text': 'BigRigRadio Live Accident Awareness',
#                'target': 1},
#               {'id': 107,
#                'keyword': 'accident',
#                'location': 'North Carolina',
#                'text': 'I-77 Mile Marker 31 South Mooresville  Iredell Vehicle Accident Ramp Closed at 8/6 1:18 PM',
#                'target': 1},
#               {'id': 112,
#                'keyword': 'accident',
#                'location': 'San Mateo County, CA',
#                'text': 'Traffic accident N CABRILLO HWY/MAGELLAN AV MIR (08/06/15 11:03:58)',
#                'target': 1},
#               {'id': 113,
#                'keyword': 'accident',
#                'location': 'North Carolina',
#                'text': 'I-77 Mile Marker 31 to 40 South Mooresville  Iredell Vehicle Accident Congestion at 8/6 1:18 PM',
#                'target': 1},
#               {'id': 114,
#                'keyword': 'accident',
#                'location': 'Njoro, Kenya',
#                'text': 'the pastor was not in the scene of the accident......who was the owner of the range rover ?',
#                'target': 1},
#               {'id': 118,
#                'keyword': 'accident',
#                'location': "Your Sister's Bedroom",
#                'text': "I was in a horrible car accident this past Sunday. I'm finally able to get around. Thank you GOD??",
#                'target': 1},
#               {'id': 120,
#                'keyword': 'accident',
#                'location': 'Arlington, TX',
#                'text': "#TruckCrash Overturns On #FortWorth Interstate http://t.co/Rs22LJ4qFp Click here if you've been in a crash&gt;http://t.co/Ld0unIYw4k",
#                'target': 1},
#               {'id': 121,
#                'keyword': 'accident',
#                'location': 'South Bloomfield, OH',
#                'text': 'Accident in #Ashville on US 23 SB before SR 752 #traffic http://t.co/hylMo0WgFI',
#                'target': 1},
#               {'id': 126,
#                'keyword': 'accident',
#                'location': nan,
#                'text': 'Carolina accident: Motorcyclist Dies in I-540 Crash With Car That Crossed Median: A motorcycle rider traveling... http://t.co/p18lzRlmy6',
#                'target': 1},
#               {'id': 128,
#                'keyword': 'accident',
#                'location': 'New Hanover County, NC',
#                'text': 'FYI CAD:FYI: ;ACCIDENT PROPERTY DAMAGE;NHS;999 PINER RD/HORNDALE DR',
#                'target': 1},
#               {'id': 129,
#                'keyword': 'accident',
#                'location': 'Maldives',
#                'text': 'RT nAAYf: First accident in years. Turning onto Chandanee Magu from near MMA. Taxi rammed into me while I was halfway turned. Everyone conf\x89Û_',
#                'target': 1},
#               {'id': 130,
#                'keyword': 'accident',
#                'location': 'Manchester, NH',
#                'text': 'Accident left lane blocked in #Manchester on Rt 293 NB before Eddy Rd stop and go traffic back to NH-3A delay of 4 mins #traffic',
#                'target': 1},
#               {'id': 131,
#                'keyword': 'accident',
#                'location': 'Wilmington, NC',
#                'text': ';ACCIDENT PROPERTY DAMAGE; PINER RD/HORNDALE DR',
#                'target': 1},
#               {'id': 133,
#                'keyword': 'accident',
#                'location': 'New Hanover County, NC',
#                'text': 'FYI CAD:FYI: ;ACCIDENT PROPERTY DAMAGE;WPD;1600 S 17TH ST',
#                'target': 1},
#               {'id': 134,
#                'keyword': 'accident',
#                'location': nan,
#                'text': '8/6/2015@2:09 PM: TRAFFIC ACCIDENT NO INJURY at 2781 WILLIS FOREMAN RD http://t.co/VCkIT6EDEv',
#                'target': 1},
#               {'id': 135,
#                'keyword': 'accident',
#                'location': 'global',
#                'text': 'Aashiqui Actress Anu Aggarwal On Her Near-Fatal Accident http://t.co/6Otfp31LqW',
#                'target': 1},
#               {'id': 136,
#                'keyword': 'accident',
#                'location': 'Alberta | Sask. | Montana',
#                'text': 'Suffield Alberta Accident https://t.co/bPTmlF4P10',
#                'target': 1},
#               {'id': 137,
#                'keyword': 'accident',
#                'location': 'Charlotte',
#                'text': '9 Mile backup on I-77 South...accident blocking the Right 2 Lanes at Exit 31 Langtree Rd...consider NC 115 or NC 150 to NC 16 as alternate',
#                'target': 1},
#               {'id': 139,
#                'keyword': 'accident',
#                'location': 'Hagerstown, MD',
#                'text': "#BREAKING: there was a deadly motorcycle car accident that happened to #Hagerstown today. I'll have more details at 5 @Your4State. #WHAG",
#                'target': 1},
#               {'id': 143,
#                'keyword': 'accident',
#                'location': nan,
#                'text': "only had a car for not even a week and got in a fucking car accident .. Mfs can't fucking drive .",
#                'target': 1},
#               {'id': 144,
#                'keyword': 'accident',
#                'location': 'UK',
#                'text': '.@NorwayMFA #Bahrain police had previously died in a road accident they were not killed by explosion https://t.co/gFJfgTodad',
#                'target': 1},
#               {'id': 196,
#                'keyword': 'airplane%20accident',
#                'location': '19.600858, -99.047821',
#                'text': 'Experts in France begin examining airplane debris found on Reunion Island: French air accident experts o... http://t.co/YVVPznZmXg #news',
#                'target': 1},
#               {'id': 197,
#                'keyword': 'airplane%20accident',
#                'location': 'Pennsylvania',
#                'text': 'Strict liability in the context of an airplane accident: Pilot error is a common component of most aviation cr... http://t.co/6CZ3bOhRd4',
#                'target': 1},
#               {'id': 199,
#                'keyword': 'airplane%20accident',
#                'location': 'Palo Alto, CA',
#                'text': 'Experts in France begin examining airplane debris found on Reunion Island: French air accident experts on Wedn... http://t.co/bKpFpOGySI',
#                'target': 1},
#               {'id': 201,
#                'keyword': 'airplane%20accident',
#                'location': nan,
#                'text': "@AlexAllTimeLow awwww they're on an airplane accident and they're gonna die what a cuties ???? good job!",
#                'target': 1},
#               {'id': 203,
#                'keyword': 'airplane%20accident',
#                'location': 'Spain but Opa-Locka, FL',
#                'text': 'family members of osama bin laden have died in an airplane accident how ironic ?????? mhmmm gov shit i suspect',
#                'target': 1},
#               {'id': 204,
#                'keyword': 'airplane%20accident',
#                'location': 'Jaipur, India',
#                'text': 'Man Goes into Airplane Engine Accident: http://t.co/TYJxrFd3St via @YouTube',
#                'target': 1},
#               {'id': 205,
#                'keyword': 'airplane%20accident',
#                'location': 'Hyderabad Telangana INDIA',
#                'text': 'Horrible Accident  Man Died In Wings of Airplane (29-07-2015) http://t.co/i7kZtevb2v',
#                'target': 1},
#               {'id': 208,
#                'keyword': 'airplane%20accident',
#                'location': 'Eagle Pass, Texas',
#                'text': 'A Cessna airplane accident in Ocampo Coahuila Mexico on July 29 2015 killed four men including a State of Coahuila government official.',
#                'target': 1},
#               {'id': 209,
#                'keyword': 'airplane%20accident',
#                'location': 'bangalore',
#                'text': '#Horrible #Accident Man Died In Wings Airplane (29-07-2015) #WatchTheVideo http://t.co/p64xRVgJIk',
#                'target': 1},
#               {'id': 210,
#                'keyword': 'airplane%20accident',
#                'location': 'Financial News and Views',
#                'text': 'Experts in France begin examining airplane debris found on Reunion Island http://t.co/LsMx2vwr3J French air accident experts on Wednesday\x89Û_',
#                'target': 1},
#               {'id': 211,
#                'keyword': 'airplane%20accident',
#                'location': nan,
#                'text': 'Experts in France begin examining airplane debris found on Reunion Island: French air accident experts on Wednesday began examining t...',
#                'target': 1},
#               {'id': 212,
#                'keyword': 'airplane%20accident',
#                'location': 'Indonesia',
#                'text': "#KCA #VoteJKT48ID mbataweel: #RIP #BINLADEN Family members who killed in an airplane's accident",
#                'target': 1},
#               {'id': 216,
#                'keyword': 'airplane%20accident',
#                'location': 'Somewhere Out There',
#                'text': 'Experts in France begin examining airplane debris found on Reunion Island: French air accident experts on... http://t.co/TagZbcXFj0 #MLB',
#                'target': 1},
#               {'id': 218,
#                'keyword': 'airplane%20accident',
#                'location': nan,
#                'text': 'This is unbelievably insane.\n#man #airport #airplane #aircraft #aeroplane #runway #accident #freaky\x89Û_ https://t.co/cezhq7CzLl',
#                'target': 1},
#               {'id': 219,
#                'keyword': 'airplane%20accident',
#                'location': 'Mumbai india',
#                'text': 'Horrible Accident |  Man Died In Wings of AirplaneåÊ(29-07-2015) http://t.co/wq3wJsgPHL',
#                'target': 1},
#               {'id': 220,
#                'keyword': 'airplane%20accident',
#                'location': 'sri lanka',
#                'text': 'Horrible Accident Man Died In Wings of Airplane (29-07-2015) http://t.co/TfcdRONRA6',
#                'target': 1},
#               {'id': 221,
#                'keyword': 'airplane%20accident',
#                'location': 'Not a U.S resident',
#                'text': 'Usama bin Ladins family dead in airplane crash. Naturally no accident.',
#                'target': 1},
#               {'id': 222,
#                'keyword': 'airplane%20accident',
#                'location': nan,
#                'text': 'Pilot Dies In Plane Crash At Car Festival https://t.co/kQ9aE6AP2B via @YouTube #Crash #Aircraft #Airplane #Pilot #Death #Accident #CarFest',
#                'target': 1},
#               {'id': 225,
#                'keyword': 'airplane%20accident',
#                'location': 'Lehigh Valley, PA',
#                'text': 'Strict liability in the context of an airplane accident - http://t.co/gibyQHhKpk',
#                'target': 1},
#               {'id': 226,
#                'keyword': 'airplane%20accident',
#                'location': 'Canada',
#                'text': 'DTN Brazil: Experts in France begin examining airplane debris found on Reunion Island: French air accident exp... http://t.co/M9IG3WQ8Lq',
#                'target': 1},
#               {'id': 229,
#                'keyword': 'airplane%20accident',
#                'location': nan,
#                'text': 'Experts in France begin examining airplane debris found on Reunion Island: French air accident experts on Wedn... http://t.co/v4SMAESLK5',
#                'target': 1},
#               {'id': 231,
#                'keyword': 'airplane%20accident',
#                'location': 'Thrissur',
#                'text': 'Horrible Accident Man Died In Wings Of \x89ÛÏAirplane\x89Û\x9d 29-07-2015. WTF You Can\x89Ûªt Believe Your EYES \x89ÛÒ... http://t.co/6fFyLAjWpS',
#                'target': 1},
#               {'id': 232,
#                'keyword': 'airplane%20accident',
#                'location': 'Havenford',
#                'text': "+ Nicole Fletcher one of a victim of crashed airplane few times ago. \n\nThe accident left a little bit trauma for her. Although she's \n\n+",
#                'target': 1},
#               {'id': 235,
#                'keyword': 'airplane%20accident',
#                'location': 'India',
#                'text': 'OMG Horrible Accident Man Died in Wings of Airplane. http://t.co/xDxDPrcPnS',
#                'target': 1},
#               {'id': 237,
#                'keyword': 'airplane%20accident',
#                'location': '92',
#                'text': "#OMG! I don't believe this. #RIP bro\n#AirPlane #Accident #JetEngine #TurboJet #Boing #G90 http://t.co/KXxnSZp6nk",
#                'target': 1},
#               {'id': 238,
#                'keyword': 'airplane%20accident',
#                'location': nan,
#                'text': 'Experts in France begin examining airplane debris found on Reunion Island: French air accident experts on Wednesday began examining t...',
#                'target': 1},
#               {'id': 240,
#                'keyword': 'airplane%20accident',
#                'location': 'Israel',
#                'text': 'I had a airplane accident.',
#                'target': 1},
#               {'id': 243,
#                'keyword': 'airplane%20accident',
#                'location': 'italy',
#                'text': 'airplane crashes on house in Colombia 12 people die in accident https://t.co/ZhJlfLBHZL',
#                'target': 1},
#               {'id': 244,
#                'keyword': 'airplane%20accident',
#                'location': 'nyc',
#                'text': 'The shooting or the airplane accident  https://t.co/iECc1JDOub',
#                'target': 1},
#               {'id': 245,
#                'keyword': 'airplane%20accident',
#                'location': 'Toronto',
#                'text': 'Could a drone cause an airplane accident? Pilots worried about use of drones esp. in close vicinity of airports http://t.co/kz35rGngJF #',
#                'target': 1},
#               {'id': 246,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': 'Early wake up call from my sister begging me to come over &amp; ride w/her in the ambulance to the hospital #RODKiai',
#                'target': 1},
#               {'id': 247,
#                'keyword': 'ambulance',
#                'location': 'Jackson',
#                'text': 'http://t.co/AY6zzcUpnz Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/sC9dNS41Mc',
#                'target': 1},
#               {'id': 248,
#                'keyword': 'ambulance',
#                'location': 'New York / Worldwide',
#                'text': 'Two air ambulances on scene of serious crash between two cars and lorry in ... - http://t.co/9pFEaQeSki http://t.co/fntG70rnkx | #EMSNe\x89Û_',
#                'target': 1},
#               {'id': 249,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': 'Twelve feared killed in Pakistani air ambulance helicopter crash - Reuters http://t.co/mDnUGVuBwN #yugvani',
#                'target': 1},
#               {'id': 252,
#                'keyword': 'ambulance',
#                'location': 'West Wales',
#                'text': "Anyone travelling Aberystwyth-Shrewsbury right now there's been an incident. Services at a halt just outside Shrews. Ambulance on scene.",
#                'target': 1},
#               {'id': 253,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': 'Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/Xum8YLcb4Q',
#                'target': 1},
#               {'id': 258,
#                'keyword': 'ambulance',
#                'location': 'Arizona ',
#                'text': '@20skyhawkmm20 @traplord_29 @FREDOSANTANA300 @LilReese300 it was hella crazy 3 fights an ambulance and a couple mosh pits ??',
#                'target': 1},
#               {'id': 261,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': '#news Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/bFeS5tWBzt #til_now #DNA',
#                'target': 1},
#               {'id': 262,
#                'keyword': 'ambulance',
#                'location': 'Amsterdam',
#                'text': 'http://t.co/7xGLah10zL Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/THmblAATzP',
#                'target': 1},
#               {'id': 266,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': 'Pakistan air ambulance helicopter crash kills nine http://t.co/8E7rY8eBMf',
#                'target': 1},
#               {'id': 269,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': 'http://t.co/FCqmKFfflW Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/vAyaYmbNgu',
#                'target': 1},
#               {'id': 270,
#                'keyword': 'ambulance',
#                'location': 'Karachi',
#                'text': 'Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/3bRme6Sn4t',
#                'target': 1},
#               {'id': 274,
#                'keyword': 'ambulance',
#                'location': '|| c h i c a g o ||',
#                'text': "when you don't know which way an ambulance is coming from &lt;&lt;",
#                'target': 1},
#               {'id': 276,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': '#reuters Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/ShzPyIQok5',
#                'target': 1},
#               {'id': 277,
#                'keyword': 'ambulance',
#                'location': 'L. A.',
#                'text': 'http://t.co/pWwpUm6RBj Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/ySpON4d6Qo',
#                'target': 1},
#               {'id': 283,
#                'keyword': 'ambulance',
#                'location': 'Lexington',
#                'text': 'http://t.co/FueRk0gWui Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/Mv7GgGlmVc',
#                'target': 1},
#               {'id': 285,
#                'keyword': 'ambulance',
#                'location': nan,
#                'text': 'http://t.co/X5YEUYLT1X Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/2UgrMd1z1n',
#                'target': 1},
#               {'id': 287,
#                'keyword': 'ambulance',
#                'location': 'USA',
#                'text': 'Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/TH9YwBbeet #worldNews',
#                'target': 1},
#               {'id': 289,
#                'keyword': 'ambulance',
#                'location': 'Hannover, Germany',
#                'text': 'Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/X2Qsjod40u #worldnews',
#                'target': 1},
#               {'id': 293,
#                'keyword': 'ambulance',
#                'location': 'Playa',
#                'text': 'http://t.co/J8TYT1XRRK Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co/9d4nAzOI94',
#                'target': 1},
#               {'id': 302,
#                'keyword': 'annihilated',
#                'location': nan,
#                'text': 'Annihilated Abs . ?? http://t.co/1xPw292tJe',
#                'target': 1},
#               {'id': 310,
#                'keyword': 'annihilated',
#                'location': 'Boston',
#                'text': 'Cop pulls drunk driver to safety SECONDS before his car is hit by train. http://t.co/tHrhKHOGcUåÊ http://t.co/tZSZmF2qxE via @ViralSpell',
#                'target': 1},
#               {'id': 313,
#                'keyword': 'annihilated',
#                'location': nan,
#                'text': 'Cop pulls drunk driver to safety SECONDS before his car is hit by train. http://t.co/C0nKGp6w03åÊ http://t.co/IMWmfDJSSn via @ViralSpell',
#                'target': 1},
#               {'id': 318,
#                'keyword': 'annihilated',
#                'location': nan,
#                'text': "@violentfeminazi I guess that's ok for Armenians since we've spent most of our history getting annihilated",
#                'target': 1},
#               {'id': 320,
#                'keyword': 'annihilated',
#                'location': nan,
#                'text': '70 years since we annihilated 100000 people instantly and became aware that we have the ability to annihilate the whole of humanity',
#                'target': 1},
#               {'id': 322,
#                'keyword': 'annihilated',
#                'location': 'London',
#                'text': 'During the 1960s the oryx a symbol of the Arabian Peninsula were annihilated by hunters. \nhttp://t.co/yangEQBUQW http://t.co/jQ2eH5KGLt',
#                'target': 1},
#               {'id': 328,
#                'keyword': 'annihilated',
#                'location': nan,
#                'text': 'Ready to get annihilated for the BUCS game',
#                'target': 1},
#               {'id': 329,
#                'keyword': 'annihilated',
#                'location': 'South 37',
#                'text': "@PhilipDuncan @breakfastone People 'annihilated by last nights weather'... Really Philip thought you would have forecast that...",
#                'target': 1},
#               {'id': 334,
#                'keyword': 'annihilated',
#                'location': nan,
#                'text': '@TomcatArts thus explaining why you were all annihilated. But the few or in this case you the only survivor evolved and became godlike',
#                'target': 1},
#               {'id': 338,
#                'keyword': 'annihilated',
#                'location': nan,
#                'text': 'Cop pulls drunk driver to safety SECONDS before his car is hit by train. http://t.co/F1BAkpNyn6åÊ http://t.co/lZXwoAyE4x via @ViralSpell',
#                'target': 1},
#               {'id': 340,
#                'keyword': 'annihilated',
#                'location': 'Swaning Around',
#                'text': 'ANNIHILATED IN DAMASCUS: SYRIAN ARMY GRINDS \x89Û÷ALLOOSH AND HIS GANG INTO THE MANURE PILE\nhttp://t.co/7rakhP3bWm',
#                'target': 1},
#               {'id': 346,
#                'keyword': 'annihilation',
#                'location': 'California, USA',
#                'text': '@rvfriedmann Hell is just a fraction of his belief of total annihilation destruction of USA @LodiSilverado @ritzy_jewels',
#                'target': 1},
#               {'id': 352,
#                'keyword': 'annihilation',
#                'location': 'Wild Wild Web',
#                'text': 'annihilating quarterstaff of annihilation',
#                'target': 1},
#               {'id': 354,
#                'keyword': 'annihilation',
#                'location': 'Spain',
#                'text': ':StarMade: :Stardate 3: :Planetary Annihilation:: http://t.co/I2hHvIUmTm via @YouTube',
#                'target': 1},
#               {'id': 356,
#                'keyword': 'annihilation',
#                'location': 'CA physically- Boston Strong?',
#                'text': 'U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/sW1sBua3mN via @Change',
#                'target': 1},
#               {'id': 360,
#                'keyword': 'annihilation',
#                'location': nan,
#                'text': 'U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... http://t.co/KPQk0C4G0M via @Change',
#                'target': 1},
#               {'id': 364,
#                'keyword': 'annihilation',
#                'location': nan,
#                'text': '@CalFreedomMom @steph93065 not to mention a major contributor to the annihilation of Israel',
#                'target': 1},
#               {'id': 365,
#                'keyword': 'annihilation',
#                'location': nan,
#                'text': '@willienelson We need help! Horses will die!Please RT &amp; sign petition!Take a stand &amp; be a voice for them! #gilbert23 https://t.co/e8dl1lNCVu',
#                'target': 1},
#               {'id': 381,
#                'keyword': 'annihilation',
#                'location': 'Ljubljana, Slovenia',
#                'text': 'Stop the Annihilation of the Salt River Wild Horses! http://t.co/wVobVVtXKg via @Change',
#                'target': 1},
#               {'id': 390,
#                'keyword': 'annihilation',
#                'location': 'Subconscious LA',
#                'text': 'World Annihilation vs Self Transformation http://t.co/pyehwodWun Aliens Attack to Exterminate Humans http://t.co/8jxqL8Cv8Z',
#                'target': 1},
#               {'id': 394,
#                'keyword': 'annihilation',
#                'location': 'Chandler, AZ',
#                'text': 'U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... http://t.co/SB5R7ShcCJ via @Change',
#                'target': 1},
#               {'id': 397,
#                'keyword': 'apocalypse',
#                'location': 'sindria',
#                'text': "ohH NO FUKURODANI DIDN'T SURVIVE THE APOCALYPSE BOKUTO FEELS HORRIBLE  my poor boy my ppor child",
#                'target': 1},
#               {'id': 404,
#                'keyword': 'apocalypse',
#                'location': 'Elk Grove, CA, USA',
#                'text': "Another hour! It's August 05 2015 at 08:02PM Here's Red Rover Zombie Apocalypse 2014! http://t.co/cf9e6TU3g7 #internetradio #collegeradi\x89Û_",
#                'target': 1},
#               {'id': 410,
#                'keyword': 'apocalypse',
#                'location': 'Austin, TX',
#                'text': "I know it's a question of interpretation but this is a sign of the apocalypse.  I called it https://t.co/my8q1uWIjn",
#                'target': 1},
#               {'id': 418,
#                'keyword': 'apocalypse',
#                'location': 'Albuquerque',
#                'text': 'And so it begins.. day one of the snow apocalypse',
#                'target': 1},
#               {'id': 424,
#                'keyword': 'apocalypse',
#                'location': 'San Antonio-ish, TX',
#                'text': "Dad bought a DVD that looks like a science doc on the front but I read the back and it's actually about the impending biblical apocalypse",
#                'target': 1},
#               {'id': 432,
#                'keyword': 'apocalypse',
#                'location': 'Buffalo NY',
#                'text': "There's a Storm over Cairo in the latest 'X-Men Apocalypse' set photo https://t.co/fS012trUDG via @YahooTV",
#                'target': 1},
#               {'id': 440,
#                'keyword': 'apocalypse',
#                'location': nan,
#                'text': 'The latest from @BryanSinger reveals #Storm is a queen in #Apocalypse @RuPaul @AlexShipppp http://t.co/oQw8Jx6rTs',
#                'target': 1},
#               {'id': 442,
#                'keyword': 'apocalypse',
#                'location': nan,
#                'text': 'Shadow boxing the apocalypse',
#                'target': 1},
#               {'id': 443,
#                'keyword': 'apocalypse',
#                'location': nan,
#                'text': 'Short Reading\n\nApocalypse 21:1023 \n\nIn the spirit the angel took me to the top of an enormous high mountain and... http://t.co/v8AfTD9zeZ',
#                'target': 1},
#               {'id': 462,
#                'keyword': 'armageddon',
#                'location': 'California, United States',
#                'text': "#PBBan (Temporary:300) hyider_ghost2 @'aRmageddon | DO NOT KILL | FLAGS ONLY | Fast XP' for Reason",
#                'target': 1},
#               {'id': 467,
#                'keyword': 'armageddon',
#                'location': 'Here And There',
#                'text': 'Armageddon https://t.co/uCSUDk3q1d',
#                'target': 1},
#               {'id': 471,
#                'keyword': 'armageddon',
#                'location': 'Florida, USA',
#                'text': 'Vladimir Putin Issues Major Warning But Is It Too Late To Escape Armageddon?\nhttp://t.co/gBxafy1m1C',
#                'target': 1},
#               {'id': 478,
#                'keyword': 'armageddon',
#                'location': 'Toronto, ON',
#                'text': '@Erker Again?? Eep! Thought of you yesterday when I saw that hella scary hail. #armageddon?',
#                'target': 1},
#               {'id': 490,
#                'keyword': 'armageddon',
#                'location': nan,
#                'text': 'Paul Craig Roberts \x89ÛÒ Vladimir Putin Issues Major Warning But Is It Too Late To Escape A http://t.co/NVfKzv5FEx #brics #roberts #russia',
#                'target': 1},
#               {'id': 509,
#                'keyword': 'army',
#                'location': 'Memphis, TN',
#                'text': 'Salvation Army hosts rally to reconnect fathers with children: The Salvation Army is hosting a back to school rally\x89Û_ http://t.co/rDjpor3AZg',
#                'target': 1},
#               {'id': 513,
#                'keyword': 'army',
#                'location': 'Studio',
#                'text': 'But if you build an army of 100 dogs and their leader is a lion all dogs will fight like a lion.',
#                'target': 1},
#               {'id': 516,
#                'keyword': 'army',
#                'location': nan,
#                'text': 'One Direction Is my pick for http://t.co/q2eBlOKeVE Fan Army #Directioners http://t.co/eNCmhz6y34 x1392',
#                'target': 1},
#               {'id': 519,
#                'keyword': 'army',
#                'location': nan,
#                'text': "VICTORINOX SWISS ARMY DATE WOMEN'S RUBBER MOP WATCH 241487 http://t.co/yFy3nkkcoH http://t.co/KNEhVvOHVK",
#                'target': 1},
#               {'id': 538,
#                'keyword': 'army',
#                'location': 'Burbank,CA',
#                'text': '@AP what a violent country get the army involved to help control the killings and bring back peace to the poor people.',
#                'target': 1},
#               {'id': 550,
#                'keyword': 'arson',
#                'location': 'Spokane, Washington',
#                'text': "Spokane authorities say they're struggling to solve arson cases like today's on Hamilton. http://t.co/Qbs2k01WzK http://t.co/mvLZIYsGLL",
#                'target': 1},
#               {'id': 551,
#                'keyword': 'arson',
#                'location': 'USA',
#                'text': 'Thousands attend a rally organized by Peace Now protesting the arson attack that took the life of an http://t.co/bvCKd9pdTi',
#                'target': 1},
#               {'id': 556,
#                'keyword': 'arson',
#                'location': 'Our Empire State',
#                'text': 'Another fake hate crime Lesbians burn their own house down. What else Is new :http://t.co/66oBQmxImb',
#                'target': 1},
#               {'id': 558,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Los Angeles Times: Arson suspect linked to 30 fires caught in Northern ... - http://t.co/xwMs1AWW8m #NewsInTweets http://t.co/TE2YeRugsi',
#                'target': 1},
#               {'id': 559,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Mourning notices for stabbing arson victims stir \x89Û÷politics of grief\x89Ûª in Israel http://t.co/eug6zHciun',
#                'target': 1},
#               {'id': 560,
#                'keyword': 'arson',
#                'location': 'Jerusalem',
#                'text': 'Mourning notices for stabbing arson victims stir \x89Û÷politics of grief\x89Ûª in Israel http://t.co/KkbXIBlAH7',
#                'target': 1},
#               {'id': 565,
#                'keyword': 'arson',
#                'location': 'Republic of Texas',
#                'text': 'Arson suspect linked to 30 fires caught in Northern California http://t.co/EJ2GHNAfHY',
#                'target': 1},
#               {'id': 567,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Trial Date Set for Man Charged with Arson Burglary http://t.co/WftCrLz32P',
#                'target': 1},
#               {'id': 568,
#                'keyword': 'arson',
#                'location': 'bajaur',
#                'text': 'After death of Palestinian toddler in arson\nattack Israel cracks down on Jewish',
#                'target': 1},
#               {'id': 569,
#                'keyword': 'arson',
#                'location': 'USA',
#                'text': 'Palestinian Teen Killed Amid Protests Against Arson Attack http://t.co/okVsImoGic',
#                'target': 1},
#               {'id': 570,
#                'keyword': 'arson',
#                'location': 'Eldoret, kenya',
#                'text': '#Kisii Police in Kisii hunt for students over failed arson plot: Police in Kisii hunt for students... http://t.co/m5SbFRrSn7 #CountyNews',
#                'target': 1},
#               {'id': 571,
#                'keyword': 'arson',
#                'location': '\x89ÛÊ\x89ÛÊ\x89ÛÊ',
#                'text': 'Mariah getting thick in the shoulders poor girl.',
#                'target': 1},
#               {'id': 575,
#                'keyword': 'arson',
#                'location': 'Miami,FL',
#                'text': 'RelaxInPR: miprv: RT latimes: Arson suspect linked to 30 fires caught in Northern California http://t.co/ylhAyfaOOu',
#                'target': 1},
#               {'id': 576,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Jewish leaders prayed at the hospital where a Palestinian family is being treated after arson http://t.co/Wf8iTK2KVx via @HuffPostRelig',
#                'target': 1},
#               {'id': 579,
#                'keyword': 'arson',
#                'location': 'Eldoret, kenya',
#                'text': '#Kisii Police in Kisii hunt for students over failed arson plot: Police in Kisii hunt for students... http://t.co/5bdrFU1duo #CountyNews',
#                'target': 1},
#               {'id': 580,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Mourning notices for stabbing arson victims stir \x89Û÷politics of grief\x89Ûª in Israel http://t.co/Q4L7Dg56JM',
#                'target': 1},
#               {'id': 584,
#                'keyword': 'arson',
#                'location': 'Jerusalem, Israel',
#                'text': 'Mourning notices for stabbing arson victims stir \x89Û÷politics of grief\x89Ûª in Israel http://t.co/GbluHRrlto',
#                'target': 1},
#               {'id': 585,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Owner of Chicago-Area Gay Bar Admits to Arson Scheme http://t.co/ZPxE3fMYNG #LGBT',
#                'target': 1},
#               {'id': 588,
#                'keyword': 'arson',
#                'location': 'Menasha, WI',
#                'text': 'Arson suspect linked to 30 fires caught in Northern California http://t.co/wnuqQAtTTP (via @latimes)',
#                'target': 1},
#               {'id': 589,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Tennessee lesbian couple faked hate crime and destroyed own home with arson\x89Û_ http://t.co/10mUEY8PXJ #Lesbian',
#                'target': 1},
#               {'id': 592,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Arson suspect linked to 30 fires caught in Northern California - Los Angeles Times http://t.co/PrRB4fhXtv',
#                'target': 1},
#               {'id': 594,
#                'keyword': 'arson',
#                'location': nan,
#                'text': 'Arson suspect linked to 30 fires caught in Northern California http://t.co/u1fuWrGK5U',
#                'target': 1},
#               {'id': 598,
#                'keyword': 'arsonist',
#                'location': 'ss',
#                'text': '@_301DC @Cloudy_goldrush i hate white people mo',
#                'target': 1},
#               {'id': 600,
#                'keyword': 'arsonist',
#                'location': 'Earth',
#                'text': 'Alleged East Bay serial arsonist arrested http://t.co/WR48AQTUm7',
#                'target': 1},
#               {'id': 604,
#                'keyword': 'arsonist',
#                'location': 'Worldwide',
#                'text': 'Suspected serial arsonist arrested in Calif. http://t.co/PzotPDGAkI',
#                'target': 1},
#               {'id': 606,
#                'keyword': 'arsonist',
#                'location': 'Bleak House',
#                'text': 'Arson suspect linked to 30 fires caught in Northern California http://t.co/mmGsyAHDzb',
#                'target': 1},
#               {'id': 614,
#                'keyword': 'arsonist',
#                'location': 'SF Bay Area',
#                'text': '#Arsonist arrested for setting many fires. WATCH tonight\x89Ûªs other #headlines: http://t.co/sqgogJ3S5r. #Nightbeat @VeronicaDLCruz #2MinuteMix',
#                'target': 1},
#               {'id': 630,
#                'keyword': 'arsonist',
#                'location': 'California',
#                'text': 'Alleged East Bay serial arsonist arrested #SanFrancisco - http://t.co/ojuHfkHVb2',
#                'target': 1},
#               {'id': 635,
#                'keyword': 'arsonist',
#                'location': 'New York',
#                'text': 'Arsonist Sets NYC Vegetarian Restaurant on Fire: Police #NewYork - http://t.co/Nr7usT3uh8',
#                'target': 1},
#               {'id': 644,
#                'keyword': 'arsonist',
#                'location': nan,
#                'text': 'Big Top Burning The True Story Of An Arsonist A Missing Girl \x89Û_ : http://t.co/QxH1H61cwD .',
#                'target': 1},
#               {'id': 646,
#                'keyword': 'attack',
#                'location': 'Dallas, TX',
#                'text': 'Stay vigilent. Civil liberties are under constant attack. #nativehuman #myreligion  https://t.co/WWu070Tjej',
#                'target': 1},
#               {'id': 651,
#                'keyword': 'attack',
#                'location': nan,
#                'text': 'http://t.co/pTKrXtZjtV  Nashville Theater Attack: Will Gun Grabbers Now Demand \x89ÛÏHatchet Control?\x89Û\x9d',
#                'target': 1},
#               {'id': 652,
#                'keyword': 'attack',
#                'location': 'Location',
#                'text': 'BREAKING: Terror Attack On\nPolice Post #Udhampur',
#                'target': 1},
#               {'id': 654,
#                'keyword': 'attack',
#                'location': nan,
#                'text': "it scares me that there's new versions of nuclear attack warnings like just knowing that governments still prepare for them",
#                'target': 1},
#               {'id': 655,
#                'keyword': 'attack',
#                'location': nan,
#                'text': 'ISIL claims suicide bombing at Saudi mosque that killed at least 15 http://t.co/Y8IcF89H6w http://t.co/t9MSnZV1Kb',
#                'target': 1},
#               {'id': 657,
#                'keyword': 'attack',
#                'location': 'Freeport IL. USA',
#                'text': 'Horrific attack on wife by muslim in Italy http://t.co/nY3l1oRZQb LiveLeak #News',
#                'target': 1},
#               {'id': 658,
#                'keyword': 'attack',
#                'location': nan,
#                'text': '\x89Ûª93 blasts accused Yeda Yakub dies in Karachi of heart attack http://t.co/mfKqyxd8XG #Mumbai',
#                'target': 1},
#               {'id': 659,
#                'keyword': 'attack',
#                'location': 'Dubai',
#                'text': '@etribune  US Drone attack kills 4-suspected militants in North Waziristan @AceBreakingNews https://t.co/jB038rdFAK',
#                'target': 1},
#               {'id': 660,
#                'keyword': 'attack',
#                'location': 'Tucson, Az',
#                'text': 'Suspect in latest theater attack had psychological issues http://t.co/3huhZxliiG',
#                'target': 1},
#               {'id': 661,
#                'keyword': 'attack',
#                'location': 'India',
#                'text': 'Militants attack police post in Udhampur; 2 SPOs injured | LiveMint http://t.co/Rptouz2iJs | http://t.co/69mLhfefhr #AllTheNews',
#                'target': 1},
#               {'id': 662,
#                'keyword': 'attack',
#                'location': 'Seattle WA',
#                'text': 'BREAKING: Obama Officials GAVE Muslim Terrorist the Weapon Used in Texas Attack http://t.co/qi8QDw5dFG',
#                'target': 1},
#               {'id': 664,
#                'keyword': 'attack',
#                'location': nan,
# ...
#                'target': 0},
#               {'id': 2175,
#                'keyword': 'catastrophic',
#                'location': nan,
#                'text': "@marginoferror I wish going custom ROM weren't so catastrophic",
#                'target': 0},
#               {'id': 2176,
#                'keyword': 'catastrophic',
#                'location': 'San Jose, CA',
#                'text': "The best part of old baseball managers wearing uniforms is the implication that if something catastrophic happens they'll grab a glove.",
#                'target': 0},
#               {'id': 2181,
#                'keyword': 'catastrophic',
#                'location': 'New York',
#                'text': '@MyVintageSoul ...of the British upper class and his manservant.  The pampered wealthy Brit causes a catastrophic shift (reversal) of...',
#                'target': 0},
#               {'id': 2186,
#                'keyword': 'catastrophic',
#                'location': 'Shirley, NY',
#                'text': '@SenSchumer Is this what U want Netanyahu leading these UNITED STATES into a CATASTROPHIC religious world war? ENOUGH already!',
#                'target': 0},
#               {'id': 2203,
#                'keyword': 'catastrophic',
#                'location': nan,
#                'text': 'Excited not only about the next 6 years of school and ensuing student debt but also catastrophic climate change in my lifetime   \n\n:D ??',
#                'target': 0},
#               {'id': 2204,
#                'keyword': 'catastrophic',
#                'location': 'Lurking',
#                'text': 'Pretty much every time the audio dies on an audio stream for a baseball game I assume catastrophic nuclear attack.',
#                'target': 0},
#               {'id': 2205,
#                'keyword': 'catastrophic',
#                'location': 'Leeds, England',
#                'text': 'Looking for a #Defendant #Catastrophic Injury Solicitor #jobs http://t.co/Gz27aUDyHa http://t.co/P4EKgC9sIG',
#                'target': 0},
#               {'id': 2207,
#                'keyword': 'catastrophic',
#                'location': 'N?? Y???.',
#                'text': '@SyringeToAnger åÇ and probably even more. But some disagreements with General Ross and the catastrophic occurrence made something clear. åÈ',
#                'target': 0},
#               {'id': 2209,
#                'keyword': 'chemical%20emergency',
#                'location': nan,
#                'text': 'Emergency Response and Hazardous Chemical Management: Principles and Practices http://t.co/4sSuyhkgRB http://t.co/TDerBtgZ2k',
#                'target': 0},
#               {'id': 2210,
#                'keyword': 'chemical%20emergency',
#                'location': 'Littleton, CO, USA',
#                'text': 'THE CHEMICAL BROTHERS to play The Armory in SF tomorrow night!: EMERGENCY BAY AREA EDM ANNOUNCEMENT \x89ÛÒ THE CHEM... http://t.co/3LN8TrHw6X',
#                'target': 0},
#               {'id': 2214,
#                'keyword': 'chemical%20emergency',
#                'location': 'London',
#                'text': '.@david_cameron Stop upsetting this bee! Listen to science not chemical companies #savebees https://t.co/NDJja4D5O8 http://t.co/l7BJSq0Y2o',
#                'target': 0},
#               {'id': 2216,
#                'keyword': 'chemical%20emergency',
#                'location': nan,
#                'text': 'THE CHEMICAL BROTHERS to play The Armory in SF tomorrow night!: EMERGENCY BAY AREA EDM ANNOUNCEMENT \x89ÛÒ THE CHEM... http://t.co/wBoGs8EjSj',
#                'target': 0},
#               {'id': 2217,
#                'keyword': 'chemical%20emergency',
#                'location': 'Wales',
#                'text': 'Sign the petition @david_cameron to protect bees instead of toxic chemical companies want to harm them! #savebees  - http://t.co/dB7ft3Yi6d',
#                'target': 0},
#               {'id': 2220,
#                'keyword': 'chemical%20emergency',
#                'location': 'Seattle, Washington',
#                'text': 'New #job opening at Downtown Emergency Service Center in #Seattle - #Chemical #Dependency Counselor or Intern #jobs http://t.co/BNRdKgXavr',
#                'target': 0},
#               {'id': 2227,
#                'keyword': 'chemical%20emergency',
#                'location': nan,
#                'text': 'Google Alert: Emergency units simulate a chemical explosion at NU http://t.co/NDgpWYxu6H',
#                'target': 0},
#               {'id': 2229,
#                'keyword': 'chemical%20emergency',
#                'location': 'Seattle, Washington',
#                'text': 'Downtown Emergency Service Center is hiring! #Chemical #Dependency Counselor or Intern in #Seattle apply now! #jobs http://t.co/SKQPWSNOin',
#                'target': 0},
#               {'id': 2230,
#                'keyword': 'chemical%20emergency',
#                'location': 'Harris County, Texas',
#                'text': 'Do you have a plan in case of a pool chemical emergency? Learn more here: http://t.co/UePPjwvLcb #watersafety @CDC',
#                'target': 0},
#               {'id': 2231,
#                'keyword': 'chemical%20emergency',
#                'location': 'Tyler, TX',
#                'text': '@pjcoyle ... need to be included in emergency planning for chemical plants. See also http://t.co/OamqqBNIce',
#                'target': 0},
#               {'id': 2235,
#                'keyword': 'chemical%20emergency',
#                'location': 'North Ferriby, East Yorkshire',
#                'text': "We know this is bad for the bees - don't give in to pressure from short term profit obsessed chemical companies... http://t.co/aNuTOopKF4",
#                'target': 0},
#               {'id': 2236,
#                'keyword': 'chemical%20emergency',
#                'location': 'Colombia',
#                'text': 'Nueva favorita: EmergeNCY feat. The Chemical Brothers / My Bits http://t.co/MET4YtZMFB @DeezerColombia',
#                'target': 0},
#               {'id': 2237,
#                'keyword': 'chemical%20emergency',
#                'location': 'Seattle, Washington',
#                'text': 'Downtown Emergency Service Center is hiring a #Chemical #Dependency Counselor or Intern apply now! #Seattle #jobs http://t.co/SKQPWSNOin',
#                'target': 0},
#               {'id': 2240,
#                'keyword': 'chemical%20emergency',
#                'location': 'Seattle, Washington',
#                'text': 'Downtown Emergency Service Center is hiring! #Chemical #Dependency Counselor or Intern in #Seattle apply now! #jobs http://t.co/HhTwAyT4yo',
#                'target': 0},
#               {'id': 2241,
#                'keyword': 'chemical%20emergency',
#                'location': 'Moscow, Russia',
#                'text': 'Day 2. Liquidation of emergency at chemical object. #USAR2015 #USAR15 #RUOR #??????????? http://t.co/gGTmDqUdDo',
#                'target': 0},
#               {'id': 2244,
#                'keyword': 'chemical%20emergency',
#                'location': nan,
#                'text': 'Please stand up for bees against profit-hungry chemical companies. Keep the ban &amp; #Savebees \nSign the petition now:\nhttps://t.co/4zsXjGV7iT',
#                'target': 0},
#               {'id': 2245,
#                'keyword': 'chemical%20emergency',
#                'location': 'Jersey City, NJ',
#                'text': '@laevantine Fortunately I reworked the plumbing on my emergency chemical shower to draw from the glitter pipe for just such an occasion',
#                'target': 0},
#               {'id': 2246,
#                'keyword': 'chemical%20emergency',
#                'location': nan,
#                'text': "@Chemical_Babe its a family emergency so I can't make it unless I have a chance to use by phone for stream.",
#                'target': 0},
#               {'id': 2254,
#                'keyword': 'cliff%20fall',
#                'location': ' Somewhere.',
#                'text': "'Go too Ibiza Pop ah Pill Get DRUNK &amp; Fall off a Cliff'. (Real Talk) @DannyJohnJules @Spencer_Fearon @ChristieLinford",
#                'target': 0},
#               {'id': 2255,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': '@D33munni @JeanNamibian noooooooo ... *proceeds to fall off a cliff*',
#                'target': 0},
#               {'id': 2256,
#                'keyword': 'cliff%20fall',
#                'location': ' Neverland ',
#                'text': 'Fuck  Neil go fall off a cliff or something.....#yr ??????',
#                'target': 0},
#               {'id': 2257,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': 'Beat the #heat. Today only Kill Cliff Free Fall $2. Pick up a #cold drink today after the #tough #crossfit... http://t.co/QaMwoJYahq',
#                'target': 0},
#               {'id': 2258,
#                'keyword': 'cliff%20fall',
#                'location': 'London, England',
#                'text': "NEWS FLASH!  Any decent billers been promoted to 'manager'? If so let me know as I want to watch your billings fall off a cliff.\n#Humble",
#                'target': 0},
#               {'id': 2262,
#                'keyword': 'cliff%20fall',
#                'location': 'norway',
#                'text': 'I regress and I slip and I fall off that cliff',
#                'target': 0},
#               {'id': 2265,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': "If you're reading this go accidentally fall off a cliff mate",
#                'target': 0},
#               {'id': 2266,
#                'keyword': 'cliff%20fall',
#                'location': '$ad $hawty',
#                'text': 'If u faved that I hope you fall off a cliff ??',
#                'target': 0},
#               {'id': 2271,
#                'keyword': 'cliff%20fall',
#                'location': 'Nigeria',
#                'text': 'Photographer Brian Ruebs endures 4500-feet climb to capture bride and groom http://t.co/BmWmpOyDIg',
#                'target': 0},
#               {'id': 2272,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': 'alex is making me watch 107 facts about minions i want to fall off a cliff help',
#                'target': 0},
#               {'id': 2273,
#                'keyword': 'cliff%20fall',
#                'location': 'NY || live easy? ',
#                'text': 'Do me a favor and fall off a cliff',
#                'target': 0},
#               {'id': 2274,
#                'keyword': 'cliff%20fall',
#                'location': 'BestCoast',
#                'text': "@AlexJacobsonPFS All Andre and Gore have to do is not fall off the cliff and we're elite on that side of the ball.",
#                'target': 0},
#               {'id': 2277,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': 'I hope they fall off a cliff.',
#                'target': 0},
#               {'id': 2278,
#                'keyword': 'cliff%20fall',
#                'location': 'BC',
#                'text': "Don't let your style fall flat this summer! Lord &amp; Cliff #thinkpink #magichairbump is your answer. Adding this... http://t.co/NmHZTB1ewM",
#                'target': 0},
#               {'id': 2279,
#                'keyword': 'cliff%20fall',
#                'location': 'Abuja, Nigeria',
#                'text': "When you're in deep sleep and then you dream you're bout to fall off a cliff then wake up while struggling to keep a balance",
#                'target': 0},
#               {'id': 2280,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': 'Currently want to drive my car off a cliff and fall to my death.',
#                'target': 0},
#               {'id': 2281,
#                'keyword': 'cliff%20fall',
#                'location': 'Colchester Essex ',
#                'text': 'I hope you fall off a cliff',
#                'target': 0},
#               {'id': 2284,
#                'keyword': 'cliff%20fall',
#                'location': 'Suplex City',
#                'text': '@punkblunts @sincerelyevelnn fall off a cliff into hell idc',
#                'target': 0},
#               {'id': 2285,
#                'keyword': 'cliff%20fall',
#                'location': 'Inside your mind.',
#                'text': 'Photographer Brian Ruebs endures 4500-feet climb to capture bride and groom http://t.co/JXhAZEBNQK',
#                'target': 0},
#               {'id': 2286,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': '@SZMNextDoor I got this cute lil cliff you can fall off of??',
#                'target': 0},
#               {'id': 2288,
#                'keyword': 'cliff%20fall',
#                'location': '36 & 38',
#                'text': 'i hope u trip n fall of a cliff after this tweet https://t.co/3hoIkDmoCB',
#                'target': 0},
#               {'id': 2294,
#                'keyword': 'cliff%20fall',
#                'location': 'New York, NY ',
#                'text': 'One day I want someone to run for the ferry fall and crack there face open for almost knocking me over just to get on a boat ??????',
#                'target': 0},
#               {'id': 2296,
#                'keyword': 'cliff%20fall',
#                'location': 'Slappin and Smackin ',
#                'text': 'Gulfport Energy - All-In Realizations Fall Off A Cliff http://t.co/CjuiGhBxyn',
#                'target': 0},
#               {'id': 2297,
#                'keyword': 'cliff%20fall',
#                'location': "DRAW A CIRCLE THAT'S THE EARTH",
#                'text': '*Jumps off of a cliff while drinking tea*\n\nThis is how British people fall off cliffs.',
#                'target': 0},
#               {'id': 2299,
#                'keyword': 'cliff%20fall',
#                'location': nan,
#                'text': 'That sounds like a really bad idea I like Yoenis but I feel like his production could fall off a huge cliff.',
#                'target': 0},
#               {'id': 2300,
#                'keyword': 'cliff%20fall',
#                'location': 'Florida, USA',
#                'text': "'I'm there!' Bride &amp; Groom on mountain cliff edge. Ha Ha just kidding. I WILL NOT EVER be there. Ha Ha - http://t.co/Io9ry1akON",
#                'target': 0},
#               {'id': 2301,
#                'keyword': 'cliff%20fall',
#                'location': 'Madrid, Comunidad de Madrid',
#                'text': 'ESN :  Cilla Black died of stroke after fall in Spain: Sir Cliff revealed he was due to visit her in Spain next\x89Û_ http://t.co/F7a66dIiYK',
#                'target': 0},
#               {'id': 2303,
#                'keyword': 'cliff%20fall',
#                'location': 'The Netherlands',
#                'text': '#NowPlaying * Cliff Richard - I Could Easily Fall (In Love With You) (&amp; Shadows) * #Internet #Nieuws #Radio On http://t.co/8LkMWp9qzw',
#                'target': 0},
#               {'id': 2306,
#                'keyword': 'collapse',
#                'location': 'Highland Park, CA',
#                'text': 'Time collapse is such a cool video technique.  https://t.co/upLFSqMr0C',
#                'target': 0},
#               {'id': 2308,
#                'keyword': 'collapse',
#                'location': 'Swan River',
#                'text': "@GeoffRickly I don't see the option to buy the full collapse vinyl with tee bundle just the waiting?",
#                'target': 0},
#               {'id': 2309,
#                'keyword': 'collapse',
#                'location': 'Kolkata, India',
#                'text': 'Warne Ponting shocked by Australian collapse - Yahoo Cricket India https://t.co/hsgkTeZUCN',
#                'target': 0},
#               {'id': 2312,
#                'keyword': 'collapse',
#                'location': 'Jubail IC, Saudi Arabia',
#                'text': "@BasilDudin The 'barbaric Saudies' as you said they relive Austrian economy. If we stop coming here many project will collapse.",
#                'target': 0},
#               ...]})

# %%
# Create split data
final_list = []
np.random.seed(args.seed)

for _, item_list in sorted(by_target.items()):

    np.random.shuffle(item_list)
    
    n_total = len(item_list)
    n_train = int(args.train_proportion * n_total)
    n_val = int(args.val_proportion * n_total)
    
    # Give data point a split attribute
    for item in item_list[:n_train]:
        item['split'] = 'train'
    
    #for item in item_list[n_train:n_train+n_val]:
    for item in item_list[n_train:]:
        item['split'] = 'val'

    # Add to final list
    final_list.extend(item_list)

# %%
train_split_df=pd.DataFrame(final_list)
train_split_df
# Out:
#          id            keyword  \
# 0      9815             trauma
# 1      4527          emergency
# 2      6540             injury
# 3      1456     body%20bagging
# 4     10566          windstorm
# ...     ...                ...
# 7608   9206  suicide%20bombing
# 7609   2540          collision
# 7610   4747           evacuate
# 7611   3505         derailment
# 7612   8172           rescuers
#
#                                              location  \
# 0     LOCAL ATLANTA NEWS 4/28/00 - 4/28/15 FREELANCER
# 1                                       Anchorage, AK
# 2                                                 NaN
# 3                                                 NaN
# 4                        she/her/your majesty/empress
# ...                                               ...
# 7608                                              NaN
# 7609                              North Highlands, CA
# 7610                                        Nashville
# 7611                                            India
# 7612                                   17th Dimension
#
#                                                    text  target  split
# 0     @RaabChar_28 @DrPhil @MorganLawGrp How do you ...       0  train
# 1     #Anchorage #Jobs Emergency Medicine - Nurse Pr...       0  train
# 2     JOBOOZOSO: USAT usatoday_nfl Michael Floyd's h...       0  train
# 3     WWE 2k15 MyCareer EP18 Tyrone body bagging dud...       0  train
# 4     I like the weird ones like Rain of Mystical or...       0  train
# ...                                                 ...     ...    ...
# 7608    Suicide bombing is just the fear of dying alone       1    val
# 7609  Traffic Collision - Ambulance Enroute: Elkhorn...       1    val
# 7610  @ahhtheenikki And from what I can tell- they r...       1    val
# 7611  Madhya Pradesh Train Derailment: Village Youth...       1    val
# 7612  AH-Mazing story of the power animal rescuers h...       1    val
#
# [7613 rows x 6 columns]

# %%
def preprocess_text(text):
    if type(text) == float:
        print(text)
    text = text.lower()
    text = re.sub(r"([!,.?:;()-,+\~^|/*'=<>])", r" \1 ", text)
    text = re.sub(r"([$%&#])", r"", text)
    #text = re.sub(r"[^a-zA-Z0-9.,! ?;:-]+", r"&", text) #Replace all special characters with '&'
    text = re.sub(r"[0-9]+", r"9", text) #Replace all numbers with 9
    return text

# %%
text='IUIU, #klkllk. lk; jkjkk! lkklkl? jkjkjk:kjkj mm n@# -po_op 989 ghgh& ghhgh%/8*'

# %%
preprocess_text(text)
# Out:
# 'iuiu ,  klkllk .  lk ;  jkjkk !  lkklkl ?  jkjkjk : kjkj mm n@ -po_op 9 ghgh ghhgh / 9 * '

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
train_split_df['text']=train_split_df.text.apply(preprocess_text)

# %%
train_split_df
# Out:
#          id            keyword  \
# 0      9815             trauma
# 1      4527          emergency
# 2      6540             injury
# 3      1456     body%20bagging
# 4     10566          windstorm
# ...     ...                ...
# 7608   9206  suicide%20bombing
# 7609   2540          collision
# 7610   4747           evacuate
# 7611   3505         derailment
# 7612   8172           rescuers
#
#                                              location  \
# 0     LOCAL ATLANTA NEWS 4/28/00 - 4/28/15 FREELANCER
# 1                                       Anchorage, AK
# 2                                                 NaN
# 3                                                 NaN
# 4                        she/her/your majesty/empress
# ...                                               ...
# 7608                                              NaN
# 7609                              North Highlands, CA
# 7610                                        Nashville
# 7611                                            India
# 7612                                   17th Dimension
#
#                                                    text  target  split
# 0     @raabchar_9 @drphil @morganlawgrp how do you s...       0  train
# 1     anchorage jobs emergency medicine - nurse prac...       0  train
# 2     joboozoso :  usat usatoday_nfl michael floyd '...       0  train
# 3     wwe 9k9 mycareer ep9 tyrone body bagging dudes...       0  train
# 4     i like the weird ones like rain of mystical or...       0  train
# ...                                                 ...     ...    ...
# 7608    suicide bombing is just the fear of dying alone       1    val
# 7609  traffic collision - ambulance enroute :  elkho...       1    val
# 7610  @ahhtheenikki and from what i can tell- they r...       1    val
# 7611  madhya pradesh train derailment :  village you...       1    val
# 7612  ah-mazing story of the power animal rescuers h...       1    val
#
# [7613 rows x 6 columns]

# %%
duble=train_split_df[train_split_df[['text']].duplicated(keep=False)].sort_values(by='text')
duble
# Out:
#          id            keyword                  location  \
# 5500   9225  suicide%20bombing                       NaN
# 7075   9207  suicide%20bombing                       NaN
# 4631  10080            typhoon      REPUBLICA DOMINICANA
# 5582   3905         devastated      REPUBLICA DOMINICANA
# 3934   4076          displaced  Pedophile hunting ground
# ...     ...                ...                       ...
# 6908   8018           refugees                       NaN
# 300    8044           refugees                       NaN
# 7225  10754           wreckage                    Punjab
# 6427  10776           wreckage                     India
# 6095  10771           wreckage                    Mumbai
#
#                                                    text  target  split
# 5500   ' suicide bombing at [location named] .  .  ....       1  train
# 7075   ' suicide bombing at [location named] .  .  ....       1    val
# 4631   ( losdelsonido )  obama declares disaster for...       1  train
# 5582   ( losdelsonido )  obama declares disaster for...       1  train
# 3934   . potus strategicpatience is a strategy for g...       0    val
# ...                                                 ...     ...    ...
# 6908  wowo-- =  =  =  9 nigerian refugees repatriate...       1    val
# 300   wowo-- =  =  =  9 nigerian refugees repatriate...       0  train
# 7225  wreckage  ' conclusively confirmed '  as from ...       1    val
# 6427  wreckage  ' conclusively confirmed '  as from ...       1  train
# 6095  wreckage  ' conclusively confirmed '  as from ...       1  train
#
# [204 rows x 6 columns]

# %%
train_split_df.text.str.split(' ', expand=False)
# Out:
# 0       [@raabchar_9, @drphil, @morganlawgrp, how, do,...
# 1       [anchorage, jobs, emergency, medicine, -, nurs...
# 2       [joboozoso, :, , usat, usatoday_nfl, michael, ...
# 3       [wwe, 9k9, mycareer, ep9, tyrone, body, baggin...
# 4       [i, like, the, weird, ones, like, rain, of, my...
#                               ...
# 7608    [suicide, bombing, is, just, the, fear, of, dy...
# 7609    [traffic, collision, -, ambulance, enroute, :,...
# 7610    [@ahhtheenikki, and, from, what, i, can, tell-...
# 7611    [madhya, pradesh, train, derailment, :, , vill...
# 7612    [ah-mazing, story, of, the, power, animal, res...
# Name: text, Length: 7613, dtype: object

# %%
train_split_df['keyword']=train_split_df['keyword'].fillna('_NaN_')

# %%
keyword_=pd.DataFrame(train_split_df.keyword.str.split('%20', expand=False))
keyword_
# Out:
#                  keyword
# 0               [trauma]
# 1            [emergency]
# 2               [injury]
# 3        [body, bagging]
# 4            [windstorm]
# ...                  ...
# 7608  [suicide, bombing]
# 7609         [collision]
# 7610          [evacuate]
# 7611        [derailment]
# 7612          [rescuers]
#
# [7613 rows x 1 columns]

# %%
keyword_.isnull().sum()
# Out:
# keyword    0
# dtype: int64

# %%
keyword_['len_']=keyword_.keyword.apply(lambda x: len(x))

# %%
keyword_['len_'].max()
# Out:
# 3

# %%
keyword_[keyword_['len_']==2]
# Out:
#                  keyword  len_
# 3        [body, bagging]     2
# 14    [bridge, collapse]     2
# 22           [body, bag]     2
# 23            [blew, up]     2
# 25      [mass, murderer]     2
# ...                  ...   ...
# 7591        [loud, bang]     2
# 7594         [war, zone]     2
# 7598  [nuclear, reactor]     2
# 7601        [heat, wave]     2
# 7608  [suicide, bombing]     2
#
# [1132 rows x 2 columns]

# %%
def context (text: list, keyword: list, context_len: int):
    indices_all=[]
    for word in keyword:
        indices=[i for i, x in enumerate(text) if ((word in x) or (x in word))]
        indices_all.extend(indices)
        
    if len(indices_all)>0:
        min_i=min(indices_all)-context_len
        max_i=max(indices_all)+context_len+1
        if min_i<0:
            min_i=0
                    
        return text[min_i:max_i]
    
    else:
        
        return text

# %%
text=['ui', 'hu','trep', 'per', 'trepi', 'ytr', 'try', 'per', 'ytro', 'io', 'po', 'op', 'po']
keyword=['uiu']
context(text, keyword, 2)
# Out:
# ['ui', 'hu', 'trep']

# %%
context_df=pd.DataFrame()

# %%
context_df['keyword']=train_split_df.keyword.str.split('%20', expand=False)
context_df['text']=train_split_df.text.str.split(' ', expand=False)
context_df
# Out:
#                  keyword                                               text
# 0               [trauma]  [@raabchar_9, @drphil, @morganlawgrp, how, do,...
# 1            [emergency]  [anchorage, jobs, emergency, medicine, -, nurs...
# 2               [injury]  [joboozoso, :, , usat, usatoday_nfl, michael, ...
# 3        [body, bagging]  [wwe, 9k9, mycareer, ep9, tyrone, body, baggin...
# 4            [windstorm]  [i, like, the, weird, ones, like, rain, of, my...
# ...                  ...                                                ...
# 7608  [suicide, bombing]  [suicide, bombing, is, just, the, fear, of, dy...
# 7609         [collision]  [traffic, collision, -, ambulance, enroute, :,...
# 7610          [evacuate]  [@ahhtheenikki, and, from, what, i, can, tell-...
# 7611        [derailment]  [madhya, pradesh, train, derailment, :, , vill...
# 7612          [rescuers]  [ah-mazing, story, of, the, power, animal, res...
#
# [7613 rows x 2 columns]

# %%
context_df['context']=context_df.apply(lambda x: context(x.text, x.keyword, 3), axis=1)
context_df['len']=context_df.context.apply(lambda x: len(x))

# %%
context_df
# Out:
#                  keyword                                               text  \
# 0               [trauma]  [@raabchar_9, @drphil, @morganlawgrp, how, do,...
# 1            [emergency]  [anchorage, jobs, emergency, medicine, -, nurs...
# 2               [injury]  [joboozoso, :, , usat, usatoday_nfl, michael, ...
# 3        [body, bagging]  [wwe, 9k9, mycareer, ep9, tyrone, body, baggin...
# 4            [windstorm]  [i, like, the, weird, ones, like, rain, of, my...
# ...                  ...                                                ...
# 7608  [suicide, bombing]  [suicide, bombing, is, just, the, fear, of, dy...
# 7609         [collision]  [traffic, collision, -, ambulance, enroute, :,...
# 7610          [evacuate]  [@ahhtheenikki, and, from, what, i, can, tell-...
# 7611        [derailment]  [madhya, pradesh, train, derailment, :, , vill...
# 7612          [rescuers]  [ah-mazing, story, of, the, power, animal, res...
#
#                                                 context  len
# 0     [do, you, self-inflict, a, wound, to, your, si...   21
# 1     [anchorage, jobs, emergency, medicine, -, nurs...   34
# 2     [joboozoso, :, , usat, usatoday_nfl, michael, ...   26
# 3     [mycareer, ep9, tyrone, body, bagging, dudes, ...   16
# 4     [i, like, the, weird, ones, like, rain, of, my...   24
# ...                                                 ...  ...
# 7608                  [suicide, bombing, is, just, the]    5
# 7609  [traffic, collision, -, ambulance, enroute, :,...   24
# 7610  [were, able, to, evacuate, all, the, ppl, so, ...   14
# 7611  [madhya, pradesh, train, derailment, :, , vill...    9
# 7612  [the, power, animal, rescuers, have, !, , a, s...   33
#
# [7613 rows x 4 columns]

# %%
context_df['len_text']=context_df.text.apply(lambda x: len(x))

# %%
context_df
# Out:
#                  keyword                                               text  \
# 0               [trauma]  [@raabchar_9, @drphil, @morganlawgrp, how, do,...
# 1            [emergency]  [anchorage, jobs, emergency, medicine, -, nurs...
# 2               [injury]  [joboozoso, :, , usat, usatoday_nfl, michael, ...
# 3        [body, bagging]  [wwe, 9k9, mycareer, ep9, tyrone, body, baggin...
# 4            [windstorm]  [i, like, the, weird, ones, like, rain, of, my...
# ...                  ...                                                ...
# 7608  [suicide, bombing]  [suicide, bombing, is, just, the, fear, of, dy...
# 7609         [collision]  [traffic, collision, -, ambulance, enroute, :,...
# 7610          [evacuate]  [@ahhtheenikki, and, from, what, i, can, tell-...
# 7611        [derailment]  [madhya, pradesh, train, derailment, :, , vill...
# 7612          [rescuers]  [ah-mazing, story, of, the, power, animal, res...
#
#                                                 context  len  len_text
# 0     [do, you, self-inflict, a, wound, to, your, si...   21        25
# 1     [anchorage, jobs, emergency, medicine, -, nurs...   34        37
# 2     [joboozoso, :, , usat, usatoday_nfl, michael, ...   26        29
# 3     [mycareer, ep9, tyrone, body, bagging, dudes, ...   16        23
# 4     [i, like, the, weird, ones, like, rain, of, my...   24        25
# ...                                                 ...  ...       ...
# 7608                  [suicide, bombing, is, just, the]    5         9
# 7609  [traffic, collision, -, ambulance, enroute, :,...   24        24
# 7610  [were, able, to, evacuate, all, the, ppl, so, ...   14        30
# 7611  [madhya, pradesh, train, derailment, :, , vill...    9        11
# 7612  [the, power, animal, rescuers, have, !, , a, s...   33        39
#
# [7613 rows x 5 columns]

# %%
count_dog = collections.defaultdict(int)
for _, row in context_df.iterrows():
    text=row.text
    for word in text:
        if '@' in word:
            count_dog[word]+=1
{k: v for k, v in sorted(count_dog.items(), key=lambda x: x[1], reverse=True)}
# Out:
# {'@youtube': 83,
#  '@': 37,
#  '@arianagrande': 11,
#  '@potus': 9,
#  '@foxnews': 9,
#  '@usatoday': 9,
#  '@change': 9,
#  '@emmerdale': 8,
#  '@justinbieber': 7,
#  '@djicemoon': 7,
#  '@stretcher': 6,
#  '@towel': 6,
#  '@mikeparractor': 6,
#  '@invalid': 5,
#  '@viralspell': 5,
#  '@youngheroesid': 5,
#  '@usagov': 5,
#  '@ap': 5,
#  '@raynbowaffair': 4,
#  '@diamondkesawn': 4,
#  '@gop': 4,
#  '@grazed': 4,
#  '@rexyy': 4,
#  '@lonewolffur': 4,
#  '@local_arsonist': 4,
#  '@realdonaldtrump': 4,
#  '@michael9sos': 4,
#  '@reuters': 4,
#  '@kurtschlichter': 4,
#  '@unsuckdcmetro': 4,
#  '@business': 3,
#  '@worldnetdaily': 3,
#  '@dannyonpc': 3,
#  '@jimmyfallon': 3,
#  '@wired': 3,
#  '@zak_bagans': 3,
#  '@tinyjecht': 3,
#  '@un': 3,
#  '@refugees': 3,
#  '@apollobrown': 3,
#  '@nickcannon': 3,
#  '@realmandyrain': 3,
#  '@itunesmusic': 3,
#  '@itunes': 3,
#  '@guardian': 3,
#  '@trubgme': 3,
#  '@witter': 3,
#  '@calum9sos': 3,
#  '@weathernetwork': 3,
#  '@claytonbryant': 3,
#  '@accionempresa': 3,
#  '@gerenciatodos': 3,
#  '@davidvonderhaar': 3,
#  '@barackobama': 3,
#  '@spinningbot': 3,
#  's@x': 3,
#  '@ebay': 3,
#  '@po_st': 3,
#  '@nytimes': 3,
#  '@ian_hellfire': 3,
#  '@foxy__siren': 3,
#  '@yahoonews': 3,
#  '@blizzard_draco': 3,
#  '@abc9': 3,
#  '9@9': 3,
#  '@tflbusalerts': 3,
#  '@smh': 3,
#  '@nbcnews': 3,
#  '@nasahurricane': 3,
#  '@sharethis': 3,
#  '@mnpdnashville': 3,
#  '@tsunami_esh': 2,
#  '@itsjustinstuart': 2,
#  '@camilacabello9': 2,
#  '@9liveonline': 2,
#  '@noah_anyname': 2,
#  '@envw9': 2,
#  '@nickcocofree': 2,
#  '@juliedicaro': 2,
#  '@jdabe9': 2,
#  '@mets': 2,
#  '@robot_rainstorm': 2,
#  '@arsonistmusic': 2,
#  '@rohnertparkdps': 2,
#  '@fedex': 2,
#  '@minhazmerchant': 2,
#  'noonan@cindynoonan-heartbreak': 2,
#  '@blizzheroes': 2,
#  '@pattonoswalt': 2,
#  '@sweet9young': 2,
#  '@timkaine': 2,
#  '@starbucks': 2,
#  '@fevwarrior': 2,
#  '@megynkelly': 2,
#  '@rockbottomradfm': 2,
#  '@drake': 2,
#  '@dailykos': 2,
#  '@corleonedaboss': 2,
#  '@david_cameron': 2,
#  '@theadvocatemag': 2,
#  '@9thetwister': 2,
#  '@thisizbwright': 2,
#  '@abu_baraa9': 2,
#  '@cnnbrk': 2,
#  '@pllolz': 2,
#  '@casper_rmg': 2,
#  '@manutd': 2,
#  '@danisnotonfire': 2,
#  '@screamqueens': 2,
#  '@originalfunko': 2,
#  '@spencers': 2,
#  '@diamorfiend': 2,
#  '@www': 2,
#  '@montetjwitter9': 2,
#  '@tomcatarts': 2,
#  '@vgbootcamp': 2,
#  '@pmarca': 2,
#  '@fouseytube': 2,
#  '@zaynmalik': 2,
#  '@meekmill': 2,
#  '@jamesmelville': 2,
#  '@fatality_us': 2,
#  '@anellatulip': 2,
#  '@prosyn': 2,
#  '@nasasolarsystem': 2,
#  '@weyrey_gidi': 2,
#  '@scottwalker': 2,
#  '@cbsbigbrother': 2,
#  '@hurricane_dolce': 2,
#  '@alexbelloli': 2,
#  '@teamhendrick': 2,
#  '@bluejays': 2,
#  '@amazon': 2,
#  '@scoopit': 2,
#  '@teamstream': 2,
#  '@mishacollins': 2,
#  '@the': 2,
#  '@jones9kyle': 2,
#  '@cnn': 2,
#  '@rightwaystan': 2,
#  '@batfanuk': 2,
#  '@aftershock_delo': 2,
#  '@bradleybrad9': 2,
#  '@meinlcymbals': 2,
#  '@msnbc': 2,
#  '@abcnews': 2,
#  '@gofundme': 2,
#  '@jamaicaobserver': 2,
#  '@cnewslive': 2,
#  '@livingsafely': 2,
#  '@_minimehh': 2,
#  '@cjoyner': 2,
#  '@cdcgov': 2,
#  '@9newsgoldcoast': 2,
#  '@fewmoretweets': 2,
#  '@peterjukes': 2,
#  '@ameenshaikh9': 2,
#  '@wordpressdotcom': 2,
#  '@themagickidraps': 2,
#  '@abc': 2,
#  '@newz_sacramento': 2,
#  '@londonfire': 2,
#  '@samanthaturne9': 2,
#  '@royalcarribean': 2,
#  '@wocowae': 2,
#  '@pmharper': 2,
#  '@slate': 2,
#  '@cityofcalgary': 2,
#  '@greenharvard': 2,
#  '@aria_ahrary': 2,
#  '@thetawniest': 2,
#  '@blutz9': 2,
#  '@newyorker': 2,
#  '@raabchar_9': 1,
#  '@drphil': 1,
#  '@morganlawgrp': 1,
#  '@madisonpa_': 1,
#  '@soonergrunt': 1,
#  '@bloopandablast': 1,
#  '@suelinflower': 1,
#  '@roguewatson': 1,
#  '@yahooschwab': 1,
#  '@argentaelite': 1,
#  '@oct9': 1,
#  '@lightumupbeast': 1,
#  '\x89ûï@thehighfessions': 1,
#  '@brandonmulcahy': 1,
#  '@fpine': 1,
#  '@sayn_ae': 1,
#  '@matt_kroschel': 1,
#  '@thetxi': 1,
#  '@gunnersfan9': 1,
#  '@d_lac': 1,
#  '@d_pagexxi': 1,
#  '@danielsahyounie': 1,
#  '@georgous__': 1,
#  '@brookesddl': 1,
#  '@justin_ling': 1,
#  '@morning_joe': 1,
#  '@reince': 1,
#  '@presssec': 1,
#  '@czallstarwes': 1,
#  '@daviskawalya': 1,
#  '@mauryn9': 1,
#  '@freegeezy9': 1,
#  '@edsheeran': 1,
#  '@mwnhappy': 1,
#  '@arobotlegion': 1,
#  '@likeavillasboas': 1,
#  '@rich_chandler': 1,
#  '@danagould': 1,
#  '@waynesteratl': 1,
#  '@romeocrow': 1,
#  '@theellenshow': 1,
#  '@wbcshirl9': 1,
#  '@shipsxanchors': 1,
#  '@crowdtappers': 1,
#  '@joinvroom': 1,
#  '@fnaf_talkmc': 1,
#  '@noahj9': 1,
#  '@david_hurn': 1,
#  '@tokteacher': 1,
#  '@quotesttg': 1,
#  '@dramaa_llama': 1,
#  '@ashberxo': 1,
#  '@mind_mischief': 1,
#  'f9ntuc9z\n@esquireattire': 1,
#  '@king_naruto_': 1,
#  '@hlportal': 1,
#  '@tonyhsieh': 1,
#  '@hoodedu': 1,
#  '@cia': 1,
#  '@demetae9': 1,
#  '@hashtagteaclub': 1,
#  '@assassinkpg': 1,
#  '@tidalhifi': 1,
#  '@bobbyofhomewood': 1,
#  '@joxroundtable': 1,
#  '@startide': 1,
#  '@sonyprousa': 1,
#  '@lumixusa': 1,
#  '@djiglobal': 1,
#  '@profbriancox': 1,
#  '@rt_america': 1,
#  '@ou_wbball': 1,
#  '@im9ad': 1,
#  '@sensanders': 1,
#  '@usarmy': 1,
#  '@brodyfrieling': 1,
#  '@hanna_brooksie': 1,
#  '@lauren_miller_9': 1,
#  '@bloodbath_tv': 1,
#  '@melrises': 1,
#  '@gayler9': 1,
#  '@wwwbigbaldhead': 1,
#  '@jessienojoke': 1,
#  '@melissaross9': 1,
#  '@bluewestlo': 1,
#  '@9tarbox': 1,
#  '@garbanzobean9': 1,
#  '@radychildrens': 1,
#  '@flunkie': 1,
#  '@untameddirewolf': 1,
#  '@weloverobdyrdek': 1,
#  '@adrian_peel': 1,
#  '@lunasagalle': 1,
#  '@synapsenkotze': 1,
#  '@atchisonsean': 1,
#  '@deb9': 1,
#  '@cleverbot': 1,
#  '@eles_kaylee': 1,
#  '@jannellix9': 1,
#  '@reign_coco': 1,
#  '@jt_ruff9': 1,
#  '@cameronhacker': 1,
#  '@mickinyman': 1,
#  '@theatlantic': 1,
#  '@ticklemeshawn': 1,
#  '@evebrigid': 1,
#  '@vickybrush': 1,
#  '@allyinwondrland': 1,
#  '@bentossell': 1,
#  '@producthunt': 1,
#  '@karinagarciaxo_': 1,
#  '@ryleedowns9': 1,
#  '@nevaehburton9': 1,
#  '@rzimmermanjr': 1,
#  '@aptly_engineerd': 1,
#  '@angusmacneilsnp': 1,
#  '@drag9nking9': 1,
#  '@lisavanderpump': 1,
#  '@freediscountbks': 1,
#  '@tr_jdavis': 1,
#  '@9tiles': 1,
#  '@zacb_': 1,
#  '@guidofawkes': 1,
#  '@mediaguido': 1,
#  '@blazingelwoods': 1,
#  '@slopeofhope': 1,
#  '@lisatoddsutton': 1,
#  '\nfollow\n@icc_realckt': 1,
#  '@dattomm': 1,
#  '@taaylordarr': 1,
#  '@juliechen': 1,
#  '@lauradeholanda': 1,
#  '@duststormfilm': 1,
#  '@cncpts': 1,
#  '@solelinks': 1,
#  'control\n@pseudojuuzo': 1,
#  '@sirbrandonknt': 1,
#  '@dinosaurdracula': 1,
#  '@longbreastyat': 1,
#  '@danryckert': 1,
#  '@drewscanlon': 1,
#  '@thetimepast': 1,
#  '@saalon': 1,
#  '@collideworship_': 1,
#  '@amumumux': 1,
#  '@biggangvh9': 1,
#  '@libertygeek9': 1,
#  '@fredolsencruise': 1,
#  '@toddstarnes': 1,
#  '@libraryeliza': 1,
#  '@taylorswift9': 1,
#  '@danielkemp9': 1,
#  '@thedailyshow': 1,
#  '@zhenghxn': 1,
#  '@cacheadvance': 1,
#  '@laevantine': 1,
#  '@detroitnews': 1,
#  '@codemew': 1,
#  '@todayng': 1,
#  '@news9buffalo': 1,
#  '@hebrooon': 1,
#  '@alexjacobsonpfs': 1,
#  '@dantwitty9': 1,
#  '@_asianshawtyy': 1,
#  '@maatmhi': 1,
#  '@molly_the_tanz': 1,
#  '@ppfa': 1,
#  '@heebsterrr_': 1,
#  '@funkylilshack': 1,
#  '@mariaf9': 1,
#  '@kristindavis': 1,
#  '@cdc': 1,
#  '@ogtomd': 1,
#  '@syringetoanger': 1,
#  '@canonusaimaging': 1,
#  '@alipaper': 1,
#  '@surf_photo': 1,
#  '@wizkidayo': 1,
#  '@missdaoh': 1,
#  '@thelegendblue': 1,
#  '@cozmo9': 1,
#  '@mzgraciebaby': 1,
#  '@officialrealrap': 1,
#  '@ageekyfangirl9': 1,
#  '@drvox': 1,
#  '@bekah__w': 1,
#  '@mogacola': 1,
#  '@zamtriossu': 1,
#  '@cameronhigdon9': 1,
#  '@willhillbet': 1,
#  '@broseidonrex': 1,
#  '@dapurplesharpie': 1,
#  '@michaelgbaron': 1,
#  '@drmartyfox': 1,
#  '@_charleyisqueen': 1,
#  '@tsunami_nopeach': 1,
#  '@awadgolf': 1,
#  '@chubychux': 1,
#  '@furiosoxv': 1,
#  '@hearitfrompa': 1,
#  '@dustinbrowder': 1,
#  '@damidnighter': 1,
#  '@doningtondash\n9am': 1,
#  '@masochisticmage': 1,
#  '@gidiexclusixe': 1,
#  '@enews': 1,
#  'trouble@niallhariss': 1,
#  '@simply_vain': 1,
#  '@morehouse9': 1,
#  '@erinmariefishy': 1,
#  '@thatrussianman': 1,
#  '@dantmatrafajlo': 1,
#  '@imawesome9': 1,
#  '@tcgreno': 1,
#  '@acebabes': 1,
#  '@healthweekly9': 1,
#  '@amateurnester': 1,
#  '@alamodc': 1,
#  '@thatpersianguy': 1,
#  '@youngsafe': 1,
#  '@alexhammerstone': 1,
#  '@kttape': 1,
#  '@skynews': 1,
#  '@marginoferror': 1,
#  '@igmpj': 1,
#  '@samajp9': 1,
#  '@soonersportstv': 1,
#  '@jwalkerlyle': 1,
#  '@jmcwrites': 1,
#  '@hgf9': 1,
#  '@cortezera': 1,
#  '@dallascowboys': 1,
#  '@janiethekillr': 1,
#  '@crimsonfuckingv': 1,
#  '@bitchl9vecannon': 1,
#  '@mageavexis': 1,
#  '@stankyboy9': 1,
#  '@elreynetwork': 1,
#  '@mattcohen9fake': 1,
#  '@madonnamking': 1,
#  '@thesewphist': 1,
#  'fuckface@wineisdumb': 1,
#  '@crabbycale': 1,
#  '@mallelis': 1,
#  '@elianaraquel': 1,
#  '@target': 1,
#  '\x89ûï@leoblakecarter': 1,
#  'mg9lpgr9rm\x89û\x9d@natasha_rideout': 1,
#  '@hopeinhearts': 1,
#  '@siren_song9': 1,
#  '@chromsucks': 1,
#  '@bigperm9': 1,
#  '@avalanche': 1,
#  '@utahgrizz': 1,
#  '@jetixrestored': 1,
#  '@wrongdejavu': 1,
#  '@leandotorg': 1,
#  '@junsuisengen': 1,
#  '@kwislo': 1,
#  '@classycolkett': 1,
#  '@gemmahentsch': 1,
#  '@dloesch': 1,
#  '@cloydrivers': 1,
#  '@songhey9': 1,
#  '@elgeotaofeeq': 1,
#  '@raychielovesu': 1,
#  '@nuggets': 1,
#  '@brokenscnecal': 1,
#  '@christycroley': 1,
#  '@hendy_9': 1,
#  '@mariasherwood9': 1,
#  '@johnjcampbell': 1,
#  '@candace_dx': 1,
#  '@sw_trains': 1,
#  '@nepd_loyko': 1,
#  '@hellotybeeren': 1,
#  '@medic9': 1,
#  '@aace_org': 1,
#  '@haley_whaley': 1,
#  '@tunes_wgg': 1,
#  '@phnotf': 1,
#  '@lesley_mariiee': 1,
#  '@graysondolan': 1,
#  '@kelworldpeace': 1,
#  '@taxstone': 1,
#  '@saku_uchiha_': 1,
#  '@ya_boi_luke': 1,
#  '@hronlinetweets': 1,
#  '@malabamiandsons': 1,
#  '@scotto9': 1,
#  '\n@randpaul': 1,
#  '@emhub': 1,
#  '@laurenjauregui': 1,
#  '@princessduck': 1,
#  '@oooureli': 1,
#  '@lightning_ooc': 1,
#  '@jolly_jinu': 1,
#  '@foxnewsinsider': 1,
#  '@tanehisicoates': 1,
#  '@heyseto': 1,
#  '@flowri': 1,
#  '@joshcorman': 1,
#  '@legacyofthesith': 1,
#  '@sagacioussaber': 1,
#  '@lordofbetrayal': 1,
#  '@sophieingle9': 1,
#  '@angharadjames9': 1,
#  '@atljw': 1,
#  '@cameronciletti': 1,
#  '@tigersjostun': 1,
#  '@chojo': 1,
#  '@msmigot': 1,
#  '@no_periferico': 1,
#  '@kaotix_blaze': 1,
#  '@crash_______': 1,
#  '@riverroaming': 1,
#  '@__ohhmyjoshh': 1,
#  '@stevenrulles': 1,
#  '@tonyakappes9': 1,
#  '@southridgelife': 1,
#  '@jeannathomas': 1,
#  '@sundercr': 1,
#  '@stormbeard': 1,
#  '@steel_lord': 1,
#  '@coach_keith9': 1,
#  '@hannomottola': 1,
#  '@trpreston9': 1,
#  '@mlrydalch': 1,
#  '@noahshack': 1,
#  '@holymileyray': 1,
#  '@mooniighthunty': 1,
#  '@slimebeast': 1,
#  '@sinkingshipindy': 1,
#  '@stonebrewingco': 1,
#  '@atlbizchron': 1,
#  '@ymcglaun': 1,
#  '@supernovalester': 1,
#  '@bestcomedyvine': 1,
#  '@_itsmegss_': 1,
#  '@eunice_njoki': 1,
#  '@eileenmfl': 1,
#  '@cw_hoops': 1,
#  '@kircut9': 1,
#  '@kmactwn': 1,
#  '@meaganerd': 1,
#  '@clnv_': 1,
#  '@mzmandilynn': 1,
#  '@infinitegrace9': 1,
#  '@emiiliexirwin': 1,
#  '@vilelunar': 1,
#  '@fotofill': 1,
#  '@eggalie': 1,
#  '@absolut_sumya9': 1,
#  '@joshsternberg': 1,
#  '@s_casualty': 1,
#  '@keampurley': 1,
#  '@dani_riot': 1,
#  '@ft': 1,
#  '@cranboonitz': 1,
#  '@hereticofethics': 1,
#  '@senschumer': 1,
#  '@euro': 1,
#  '@turnedonfetaboo': 1,
#  '@hsjb9': 1,
#  '@ghostoftheav': 1,
#  '@montroseband': 1,
#  '@crystal_blaz': 1,
#  '@markwschaefer': 1,
#  '@eric_tsunami': 1,
#  '@_reddevil9life_': 1,
#  '@rokiieee_': 1,
#  '@codythompson9': 1,
#  '@questergirl': 1,
#  '@sarahksilverman': 1,
#  '@jrlallo': 1,
#  '@tweetinglew': 1,
#  '@tersestuff': 1,
#  '@chikislizeth9': 1,
#  '@femalegilgamesh': 1,
#  '@thetshirtkid': 1,
#  '@audaciousspunk': 1,
#  '@myvintagesoul': 1,
#  '@soapscoop': 1,
#  '@kallemattson': 1,
#  '@ik9len': 1,
#  '@rawfoodbliss': 1,
#  '@jasminehuerta9': 1,
#  '@daretotaha': 1,
#  '@texansdc': 1,
#  '@kylekrenek': 1,
#  '@zepp9': 1,
#  '@frobeus_ns': 1,
#  '@rachelrofe': 1,
#  '@nbc': 1,
#  '@glassanimals': 1,
#  '@mi_country_hick': 1,
#  '@myrtlegroggins': 1,
#  '@morbidmovies': 1,
#  '@ssssnell': 1,
#  '@mochichiiiii': 1,
#  '@hikagezero': 1,
#  '@_explicitpretty': 1,
#  '@dccc': 1,
#  '@vj9': 1,
#  '@lawrence': 1,
#  '@jbouie': 1,
#  '@mmfa': 1,
#  '@tammy_w9': 1,
#  '@elijahmallari': 1,
#  '@eytay': 1,
#  '@neur9sis': 1,
#  '@alexandrapullin': 1,
#  '@cod9sandscrims': 1,
#  '@empirikgaming': 1,
#  '@codawscrims': 1,
#  '@9tp_kotc': 1,
#  '@9tpfa': 1,
#  '@aftershock_org': 1,
#  '@titortau': 1,
#  '@sodamntrue': 1,
#  '@acmilan': 1,
#  '@ego_resolution': 1,
#  '@destinythegame': 1,
#  '@bungie': 1,
#  '@playstation': 1,
#  '@flavafraz9': 1,
#  '@starflame_girl': 1,
#  '@stupid_niggr': 1,
#  '@deniseromano': 1,
#  '@phdsquares': 1,
#  '@chestertweetsuk': 1,
#  '@joshacagan': 1,
#  '@carsonrex': 1,
#  '@spaceangelseven': 1,
#  '@theeconomist': 1,
#  '@newscomauhq': 1,
#  '@damnaarielle': 1,
#  '@nolesfan9': 1,
#  '@nutsandboltssp': 1,
#  '@honeybunzgem': 1,
#  '@primalkitchen': 1,
#  '@whippenz': 1,
#  '@himeruisu': 1,
#  '@chxrmingprince': 1,
#  '@jones_luna': 1,
#  '@sapphirescallop': 1,
#  '@jaureguiswisdom': 1,
#  '@thecomedyquote': 1,
#  '@9shadezofgrey': 1,
#  '@p9perez': 1,
#  '@adanne___': 1,
#  '@rhee9': 1,
#  '@deliciousvomit': 1,
#  '@alexis_sanchez': 1,
#  '@sriramk': 1,
#  '@dlin9': 1,
#  '@thejonesesvoice': 1,
#  '@cortneymo_': 1,
#  '@crowtherjohn': 1,
#  '@effiedeans': 1,
#  '@ashghebranious': 1,
#  '@pioneerpress\n\nhttp': 1,
#  '@joegoodmanjr': 1,
#  '@limpar9': 1,
#  '@aubilenon': 1,
#  '@markkriegsman': 1,
#  '@omar_molina9': 1,
#  '@milioooo_': 1,
#  '@hail_zel': 1,
#  '@blizzard_fans': 1,
#  '@lemairelee': 1,
#  '@danharmon': 1,
#  '@uriminzok': 1,
#  '@__srajapakse__': 1,
#  '@redcoatjackpot': 1,
#  '@art_brut_': 1,
#  '@__scrambledeggs': 1,
#  '@emilyschuman': 1,
#  '@squeaver': 1,
#  '@indiepopmom': 1,
#  '@stacedemon': 1,
#  '@weebly': 1,
#  '@nikistitz': 1,
#  '@that_fat_guy': 1,
#  '@aberdeenfc': 1,
#  '@aberdeenfanpage': 1,
#  '\n@armageddon': 1,
#  '@theemobrago': 1,
#  '@safyuan': 1,
#  '@gloriavelez': 1,
#  '@worldnetdailyhomosexuality': 1,
#  '@yahoo9': 1,
#  '@nprfreshair': 1,
#  '@savannahross_9': 1,
#  '@ophiuchus9': 1,
#  '@sammysosita': 1,
#  '@missleylaha': 1,
#  '@kerrykatona9': 1,
#  '@slikrickdarula': 1,
#  '@xeni': 1,
#  '@audreyp9': 1,
#  '@teena_9': 1,
#  '@darryl_brooks': 1,
#  '@elitesportsny': 1,
#  '@lopezandthelion': 1,
#  '@steveycheese9': 1,
#  '@mapmyrun': 1,
#  '@macbreck': 1,
#  '@atlarnxx': 1,
#  '@brittsand9': 1,
#  '@tprimo9': 1,
#  '@djeddygnj': 1,
#  '@uber': 1,
#  '@zachlowe_nba': 1,
#  '@stuckinbooks': 1,
#  '@robertoneill9': 1,
#  '@dieanpink9': 1,
#  '@yu_nita9': 1,
#  '@jlabuz': 1,
#  '@behindashield': 1,
#  '@wars_goddess': 1,
#  '@fiendnikki': 1,
#  '@bonhomme9': 1,
#  '@catoinstitute': 1,
#  '@treyarch': 1,
#  '@themale_madonna': 1,
#  'rt@irishirr\n@mchapmanwsaz': 1,
#  '@wsaz_brittany': 1,
#  '@kellyannwx': 1,
#  '@memenaar': 1,
#  '@fantosex': 1,
#  '@annealiz9': 1,
#  '@tellyfckngo': 1,
#  '@jaycootchi': 1,
#  '@uptown_jorge': 1,
#  '@wonderousallure': 1,
#  '@soak': 1,
#  '@thewebbeffect9': 1,
#  '@carolinagutierr': 1,
#  '@burberryant': 1,
#  '@dauntedpsyche': 1,
#  '@jj_dirty': 1,
#  '@mlstransfers': 1,
#  '@greggmair': 1,
#  '@i_electrocute': 1,
#  '@mccauleysdesign': 1,
#  '@abysmaljoiner': 1,
#  '@dyamiplotke': 1,
#  '@thatwitchem': 1,
#  '@emmachosenone': 1,
#  '@jessienovoarp': 1,
#  '@jessie_novoa_': 1,
#  '@liana_novoa': 1,
#  '@djryanwolf': 1,
#  '@djcoreygrand': 1,
#  '@djknyce': 1,
#  '@djoneplustwo': 1,
#  '@officialcoredjs': 1,
#  '@iamtonyneal': 1,
#  '@_wildfire__': 1,
#  '@auntiedote': 1,
#  '@rioslade': 1,
#  '@locke_wiggins': 1,
#  '@akarb9': 1,
#  '@telegraphworld': 1,
#  '@jusreign': 1,
#  '@harbhajan_singh': 1,
#  '@stuartbroad9': 1,
#  '@daborsch': 1,
#  '@rosemarytravale': 1,
#  '@julian_lage': 1,
#  '@grantgordy': 1,
#  '@rossmartin9': 1,
#  '@okgabby_': 1,
#  '@roanoketimes': 1,
#  '@eganator9': 1,
#  '@deezercolombia': 1,
#  '@comcastcares': 1,
#  '@quora': 1,
#  '@aiginsurance': 1,
#  '@imsushickoflove': 1,
#  '@alekalicante': 1,
#  '@faze_rain': 1,
#  '@james_justus': 1,
#  '@fallontonight': 1,
#  '@rainforestresq': 1,
#  '@9hvzlaradio': 1,
#  '@bcfcticketlady': 1,
#  '@mr_aamir_javaid': 1,
#  '@nkulw': 1,
#  '@katiekatcubs': 1,
#  '@marvel': 1,
#  '@dccomics': 1,
#  '@imagecomics': 1,
#  '@darkhorsecomics': 1,
#  '@idwpublishing': 1,
#  '@ma9route': 1,
#  '@bonnieg9': 1,
#  '@deldryden': 1,
#  '@coreyashe': 1,
#  '@kaylak9': 1,
#  '@charlesdagnall': 1,
#  '@lightning_wolf_': 1,
#  '@engineshed': 1,
#  '@flames_nation': 1,
#  '@sidelinesavage': 1,
#  '@catsandsyrup': 1,
#  '@lexi_purduee': 1,
#  '@attackonstiles': 1,
#  '@smoak_queen': 1,
#  '@girlthatsrio': 1,
#  '@deosl9': 1,
#  '@xavier_marquis': 1,
#  '@jeromekem': 1,
#  '@vienna_butcher': 1,
#  '@weapon_x_music': 1,
#  '@be_ram9s': 1,
#  '@rtrrtcoach': 1,
#  '@_doofus_': 1,
#  '@pjcoyle': 1,
#  '@abcnews9': 1,
#  '@peterdutton_mp': 1,
#  '@ladyfleur': 1,
#  '@gpaulista9': 1,
#  '@jackwilshere': 1,
#  '@kainyusanagi': 1,
#  '@grummz': 1,
#  '@pixelcanuck': 1,
#  '@youssefyamani': 1,
#  '@chaboyyhd': 1,
#  '@benignovito': 1,
#  '@libertybell9': 1,
#  'battle\n\n@9moferadio': 1,
#  '@heavybag9': 1,
#  '@battle_dom': 1,
#  '@qotring': 1,
#  '@battlerapchris': 1,
#  '@hughes9': 1,
#  '@laphamsquart': 1,
#  '@brrookkllyynnr': 1,
#  '@wisdc': 1,
#  '@rihanna': 1,
#  '@annmarieronan': 1,
#  '@niamhosullivanx': 1,
#  '@bellalinn': 1,
#  '@suny_orange': 1,
#  '@azimel': 1,
#  '@machinegunkelly': 1,
#  '@parentsacrossam': 1,
#  '@billgates': 1,
#  '@stephen_georg': 1,
#  '@akgovbillwalker': 1,
#  '@troyslaby9': 1,
#  '@mlg': 1,
#  '@ijustine': 1,
#  '@emily9everever': 1,
#  '@annajhm': 1,
#  '@jcomanse': 1,
#  '@paul_staubs': 1,
#  '@rslm9': 1,
#  '@blanktgt': 1,
#  '\x89ûï@leejasper': 1,
#  '@noahcrothman': 1,
#  '@raineishida': 1,
#  '@therealrittz': 1,
#  '@silent9siris': 1,
#  '@resolutevanity': 1,
#  '@kasad9lla': 1,
#  '@capicapricapri': 1,
#  '@brento_bento': 1,
#  '@daorcey': 1,
#  '@nsit_': 1,
#  '@ddnewslive': 1,
#  '@nitishkumar': 1,
#  '@arvindkejriwal': 1,
#  '@@narendramodi': 1,
#  '@dannyraynard': 1,
#  '@davidolszak': 1,
#  '@demolition_d': 1,
#  '@victoriagittins': 1,
#  '@danhrothschild': 1,
#  '@devinjoslyn': 1,
#  '@nicolaclements9': 1,
#  '@cityofhummus': 1,
#  '@ilnewsflash': 1,
#  '@kristenkoin9': 1,
#  '@kyrikoni': 1,
#  '@expressandstar': 1,
#  '@mattmosley': 1,
#  '@johnsontionne': 1,
#  '@battleroyalemod': 1,
#  '@kuualohax': 1,
#  '@barbi_twins': 1,
#  '@funkflex': 1,
#  '@bbctms': 1,
#  '@9hif': 1,
#  '@anonchimp': 1,
#  '@teafrystlik': 1,
#  '@billboard': 1,
#  '@crobscarla': 1,
#  '@amaramin9': 1,
#  '@uabstephenlong': 1,
#  '@courtlizcamp': 1,
#  '@dinallyhot': 1,
#  '@christinartnd': 1,
#  '@reddit': 1,
#  '@chemical_babe': 1,
#  '@stephaniemarija': 1,
#  '@davidcovucci': 1,
#  '@torontorc': 1,
#  '@kynespeace': 1,
#  '@panic': 1,
#  '@gassymexican': 1,
#  '@salmanmydarling': 1,
#  '@chrisdyson9': 1,
#  '@bigburgerboi9': 1,
#  '@skarletan': 1,
#  '@god': 1,
#  '@luzukokoti': 1,
#  '@detroitpls': 1,
#  '@asterpuppet': 1,
#  '@grtvnews': 1,
#  '@bv': 1,
#  '@j9bone': 1,
#  '@huffpostcomedy': 1,
#  '@abandonedpics': 1,
#  '@homukami': 1,
#  '@heyot9': 1,
#  '@silverhusky': 1,
#  '@chuckswindoll': 1,
#  '@iflcanada': 1,
#  '@josebasedgod': 1,
#  '@lenn_len': 1,
#  '@perkpearl': 1,
#  '@envyseven': 1,
#  '@itsnasb': 1,
#  '@pfannebeckers': 1,
#  '@caixxum9sos': 1,
#  '@khqa': 1,
#  '@darkndtatted': 1,
#  '@pixeljanosz': 1,
#  '@angelheartnight': 1,
#  '@lasvegaslocally': 1,
#  '@vitalvegas': 1,
#  '@el_torro_loco': 1,
#  '@vixmeldrew': 1,
#  '@theburnageblue': 1,
#  '@newsarama': 1,
#  '@bdisgusting': 1,
#  '@latechwatch': 1,
#  '@jamienye': 1,
#  '@mofanon': 1,
#  '@papcrdoll': 1,
#  '@halfhourhotel': 1,
#  '@edgarsgift': 1,
#  '@lovelylikelaura': 1,
#  '@thebuffshow': 1,
#  '@thetwisterokc': 1,
#  '@shaniatwain': 1,
#  '@hienshi': 1,
#  '@gbay9': 1,
#  '@kevinbacon': 1,
#  '@woundedpigeon': 1,
#  '@akcsl': 1,
#  '@shantaeskyy': 1,
#  '@pete_r_knox': 1,
#  '@gemmasterful': 1,
#  '@blizzard_gamin': 1,
#  '@oliviaapalmerr': 1,
#  '@chief__cg': 1,
#  '@theghostparty': 1,
#  'am@so@sorry': 1,
#  '@_itzsteven': 1,
#  '@xdojjjj': 1,
#  '@whopper_jr_9': 1,
#  '@raidersreporter': 1,
#  '@9thegame': 1,
#  '@thenissonian': 1,
#  '@rejectdcartoons': 1,
#  '@blanksocietyx': 1,
#  '@jyheffect': 1,
#  '@ruddyyyyyy': 1,
#  '@jamiegriff9': 1,
#  '@johngreen': 1,
#  '@robthier_en': 1,
#  '@mustachemurse': 1,
#  '@dateswhitecoats': 1,
#  '@furtrix': 1,
#  '@_bookofdaniel': 1,
#  '@ushiocomics': 1,
#  '@kinkyconnors': 1,
#  '@ciaramckendry': 1,
#  '@khadidon': 1,
#  '@hazelannmac': 1,
#  '@baileysmsteach': 1,
#  '@j9lyon': 1,
#  '@jamessnyder9': 1,
#  '@phiddleface': 1,
#  '@b9fowler': 1,
#  '@joelsherman9': 1,
#  '\n\n@calum9chambers': 1,
#  '@kaputt9': 1,
#  '@radioriffrocks': 1,
#  '@booksbyroger': 1,
#  '@tj_robertson9': 1,
#  '@hinterestin': 1,
#  '@mommyisbomb': 1,
#  '@cwheate': 1,
#  '@danemillar9': 1,
#  '@charlieputh': 1,
#  '@nykaed_': 1,
#  '@astros': 1,
#  '@sexydragonmagic': 1,
#  '@aphyr': 1,
#  '@wild_lionx9': 1,
#  '@ririnsider': 1,
#  '@neanea9': 1,
#  '@olrules': 1,
#  '@abran_caballero': 1,
#  '@spicybreads': 1,
#  '@coxytown': 1,
#  '@stevenontwatter': 1,
#  '@pussyxdestroyer': 1,
#  '@gfrost9': 1,
#  '@jeffpalmer9': 1,
#  '@mlb': 1,
#  '@wowsavannah': 1,
#  ...}

# %%
''''count_dig = collections.defaultdict(int)
for _, row in context_df.iterrows():
    text=row.text
    for word in text:
        if '9' in word:
            count_dig[word]+=1
{k: v for k, v in sorted(count_dig.items(), key=lambda x: x[1], reverse=True)}'''
# Out:
# "'count_dig = collections.defaultdict(int)\nfor _, row in context_df.iterrows():\n    text=row.text\n    for word in text:\n        if '9' in word:\n            count_dig[word]+=1\n{k: v for k, v in sorted(count_dig.items(), key=lambda x: x[1], reverse=True)}"

# %%
context_df['dif_len']=context_df.len_text-context_df.len
context_df['dif_len'].mean()
# Out:
# 4.142782083278602

# %%
train_split_not_dubl=train_split_df.drop_duplicates(subset=['text'],keep='first')
train_split_not_dubl
# Out:
#          id            keyword  \
# 0      9815             trauma
# 1      4527          emergency
# 2      6540             injury
# 3      1456     body%20bagging
# 4     10566          windstorm
# ...     ...                ...
# 7607   4742           evacuate
# 7608   9206  suicide%20bombing
# 7609   2540          collision
# 7610   4747           evacuate
# 7612   8172           rescuers
#
#                                              location  \
# 0     LOCAL ATLANTA NEWS 4/28/00 - 4/28/15 FREELANCER
# 1                                       Anchorage, AK
# 2                                                 NaN
# 3                                                 NaN
# 4                        she/her/your majesty/empress
# ...                                               ...
# 7607                                              NaN
# 7608                                              NaN
# 7609                              North Highlands, CA
# 7610                                        Nashville
# 7612                                   17th Dimension
#
#                                                    text  target  split
# 0     @raabchar_9 @drphil @morganlawgrp how do you s...       0  train
# 1     anchorage jobs emergency medicine - nurse prac...       0  train
# 2     joboozoso :  usat usatoday_nfl michael floyd '...       0  train
# 3     wwe 9k9 mycareer ep9 tyrone body bagging dudes...       0  train
# 4     i like the weird ones like rain of mystical or...       0  train
# ...                                                 ...     ...    ...
# 7607  sooo police dispatch said there was a person t...       1    val
# 7608    suicide bombing is just the fear of dying alone       1    val
# 7609  traffic collision - ambulance enroute :  elkho...       1    val
# 7610  @ahhtheenikki and from what i can tell- they r...       1    val
# 7612  ah-mazing story of the power animal rescuers h...       1    val
#
# [7483 rows x 6 columns]

# %%
train_split_not_dubl.to_csv(args.train_split_csv, index=False)

# %%
pd.read_csv(args.train_split_csv)
# Out:
#          id            keyword  \
# 0      9815             trauma
# 1      4527          emergency
# 2      6540             injury
# 3      1456     body%20bagging
# 4     10566          windstorm
# ...     ...                ...
# 7478   4742           evacuate
# 7479   9206  suicide%20bombing
# 7480   2540          collision
# 7481   4747           evacuate
# 7482   8172           rescuers
#
#                                              location  \
# 0     LOCAL ATLANTA NEWS 4/28/00 - 4/28/15 FREELANCER
# 1                                       Anchorage, AK
# 2                                                 NaN
# 3                                                 NaN
# 4                        she/her/your majesty/empress
# ...                                               ...
# 7478                                              NaN
# 7479                                              NaN
# 7480                              North Highlands, CA
# 7481                                        Nashville
# 7482                                   17th Dimension
#
#                                                    text  target  split
# 0     @raabchar_9 @drphil @morganlawgrp how do you s...       0  train
# 1     anchorage jobs emergency medicine - nurse prac...       0  train
# 2     joboozoso :  usat usatoday_nfl michael floyd '...       0  train
# 3     wwe 9k9 mycareer ep9 tyrone body bagging dudes...       0  train
# 4     i like the weird ones like rain of mystical or...       0  train
# ...                                                 ...     ...    ...
# 7478  sooo police dispatch said there was a person t...       1    val
# 7479    suicide bombing is just the fear of dying alone       1    val
# 7480  traffic collision - ambulance enroute :  elkho...       1    val
# 7481  @ahhtheenikki and from what i can tell- they r...       1    val
# 7482  ah-mazing story of the power animal rescuers h...       1    val
#
# [7483 rows x 6 columns]

# %%
s='tytyty,<'
'9', 't' not in s
# Out:
# ('9', False)

# %%
c=0
for p in string.punctuation:
    if p in s:
        c+=1
c
# Out:
# 2

# %%
train_split_not_dubl.target.sum()/len(train_split_not_dubl)
# Out:
# 0.4256314312441534
